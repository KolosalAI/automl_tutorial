# %% [markdown]
# # 🚀 Kolosal AutoML Tutorial: Optimize Your Configuration
#
# This section sets up the key modules from the `kolosal_automl` library that enable automated machine learning.
#
# ### Components
# - **`MLTrainingEngine`**: Manages model selection, training, evaluation, and reporting.
# - **`DeviceOptimizer`**: Detects available hardware (CPU/GPU) and suggests the best configuration for performance.
#
# ### Outcome
# All necessary classes are imported and ready for instantiation.

# %% [markdown]
# # 📦 Import Essential Libraries
#
# This cell imports the core components from the Kolosal AutoML library needed for our machine learning pipeline.
#
# ### Imported Components:
# - **`MLTrainingEngine`**: The main engine that handles model training, evaluation, and management
# - **`DeviceOptimizer`**: Automatically detects and optimizes hardware configuration (CPU/GPU)
# - **`MLTrainingEngineConfig`**: Configuration class for training parameters
# - **`TaskType`**: Enum for specifying machine learning task types (regression, classification)
#
# ### Why These Imports?
# These modules provide the foundation for automated machine learning with optimal hardware utilization.

# %%
from kolosal_automl.modules.engine.train_engine import MLTrainingEngine
from kolosal_automl.modules.device_optimizer import DeviceOptimizer
from kolosal_automl.modules.configs import MLTrainingEngineConfig, TaskType
# Out:
# Warning: Optimization modules not available: No module named 'modules'

# %% [markdown]
# # ⚙️ Training Engine Configuration
#
# We now configure the AutoML pipeline to optimize for regression tasks using your machine’s hardware resources.
#
# ### Steps
# - **Device Optimization**: Automatically detect and apply the best hardware configuration using `DeviceOptimizer`.
# - **Task Type**: Set to `regression` to predict continuous numerical values.
# - **Engine Initialization**: Instantiate `MLTrainingEngine` with the optimal config.
#
# ### Outcome
# A `MLTrainingEngine` object is ready to run regression training using an optimized setup.

# %%
# Create device optimizer with performance optimization mode
optimizer = DeviceOptimizer(optimization_mode="performance")

# Get optimal training engine configuration
training_config = optimizer.get_optimal_training_engine_config()

# Set the task type to regression (configuration supports both string and enum)
training_config.task_type = TaskType.REGRESSION

# Create the training engine with the optimized configuration
training_engine = MLTrainingEngine(training_config)
# Out:
# 2025-08-06 20:43:18,513 - WARNING - cpu_device_optimizer - Failed to check advanced CPU features on Windows: Command 'wmic cpu get Name' returned non-zero exit status 1.
# 2025-08-06 20:43:18,787 - INFO - cpu_device_optimizer - ==================================================
# 2025-08-06 20:43:18,789 - INFO - cpu_device_optimizer - System Overview: Laptop-Evint (Windows 10)
# 2025-08-06 20:43:18,790 - INFO - cpu_device_optimizer - Environment: cloud
# 2025-08-06 20:43:18,790 - INFO - cpu_device_optimizer - Optimization Mode: performance
# 2025-08-06 20:43:18,791 - INFO - cpu_device_optimizer - --------------------------------------------------
# 2025-08-06 20:43:18,791 - INFO - cpu_device_optimizer - CPU: Intel64 Family 6 Model 154 Stepping 3, GenuineIntel
# 2025-08-06 20:43:18,791 - INFO - cpu_device_optimizer - CPU Cores: 14 physical, 20 logical
# 2025-08-06 20:43:18,792 - INFO - cpu_device_optimizer - CPU Freq (MHz): Current=2300, Min=0, Max=2300
# 2025-08-06 20:43:18,793 - INFO - cpu_device_optimizer - CPU Features: AVX=False, AVX2=False, AVX512=False, SSE4=False, FMA=False, NEON=False
# 2025-08-06 20:43:18,794 - INFO - cpu_device_optimizer - Memory: 63.67 GB total, 57.30 GB usable, 33.63 GB available
# 2025-08-06 20:43:18,794 - INFO - cpu_device_optimizer - Swap Memory: 4.00 GB
# 2025-08-06 20:43:18,796 - INFO - cpu_device_optimizer - Disk (@C:\Users\Evint): 930.51 GB total, 48.25 GB free, SSD=False
# 2025-08-06 20:43:18,796 - INFO - cpu_device_optimizer - ==================================================
# 2025-08-06 20:43:18,787 - INFO - cpu_device_optimizer - ==================================================
# 2025-08-06 20:43:18,789 - INFO - cpu_device_optimizer - System Overview: Laptop-Evint (Windows 10)
# 2025-08-06 20:43:18,790 - INFO - cpu_device_optimizer - Environment: cloud
# 2025-08-06 20:43:18,790 - INFO - cpu_device_optimizer - Optimization Mode: performance
# 2025-08-06 20:43:18,791 - INFO - cpu_device_optimizer - --------------------------------------------------
# 2025-08-06 20:43:18,791 - INFO - cpu_device_optimizer - CPU: Intel64 Family 6 Model 154 Stepping 3, GenuineIntel
# 2025-08-06 20:43:18,791 - INFO - cpu_device_optimizer - CPU Cores: 14 physical, 20 logical
# 2025-08-06 20:43:18,792 - INFO - cpu_device_optimizer - CPU Freq (MHz): Current=2300, Min=0, Max=2300
# 2025-08-06 20:43:18,793 - INFO - cpu_device_optimizer - CPU Features: AVX=False, AVX2=False, AVX512=False, SSE4=False, FMA=False, NEON=False
# 2025-08-06 20:43:18,794 - INFO - cpu_device_optimizer - Memory: 63.67 GB total, 57.30 GB usable, 33.63 GB available
# 2025-08-06 20:43:18,794 - INFO - cpu_device_optimizer - Swap Memory: 4.00 GB
# 2025-08-06 20:43:18,796 - INFO - cpu_device_optimizer - Disk (@C:\Users\Evint): 930.51 GB total, 48.25 GB free, SSD=False
# 2025-08-06 20:43:18,796 - INFO - cpu_device_optimizer - ==================================================
# 2025-08-06 20:43:18,799 - INFO - MLTrainingEngine - Experiment tracking enabled
# 2025-08-06 20:43:18,800 - INFO - MLTrainingEngine - Data preprocessor skipped for fast initialization
# 2025-08-06 20:43:18,800 - INFO - kolosal_automl.modules.engine.batch_processor - Memory-aware batch processing enabled
# 2025-08-06 20:43:18,802 - INFO - MLTrainingEngine - Batch processor initialized
# 2025-08-06 20:43:18,804 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Advanced resource management configured with 4 threads
# 2025-08-06 20:43:18,799 - INFO - MLTrainingEngine - Experiment tracking enabled
# 2025-08-06 20:43:18,800 - INFO - MLTrainingEngine - Data preprocessor skipped for fast initialization
# 2025-08-06 20:43:18,800 - INFO - kolosal_automl.modules.engine.batch_processor - Memory-aware batch processing enabled
# 2025-08-06 20:43:18,802 - INFO - MLTrainingEngine - Batch processor initialized
# 2025-08-06 20:43:18,804 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Advanced resource management configured with 4 threads
# 2025-08-06 20:43:20,110 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - SIMD optimizer initialized
# 2025-08-06 20:43:20,112 - INFO - kolosal_automl.modules.engine.quantizer - Quantizer initialized with QuantizationType.INT8 type and QuantizationMode.DYNAMIC mode
# 2025-08-06 20:43:20,113 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Quantizer initialized with QuantizationType.INT8 type
# 2025-08-06 20:43:20,114 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Result cache initialized with 1000 entries
# 2025-08-06 20:43:20,110 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - SIMD optimizer initialized
# 2025-08-06 20:43:20,112 - INFO - kolosal_automl.modules.engine.quantizer - Quantizer initialized with QuantizationType.INT8 type and QuantizationMode.DYNAMIC mode
# 2025-08-06 20:43:20,113 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Quantizer initialized with QuantizationType.INT8 type
# 2025-08-06 20:43:20,114 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Result cache initialized with 1000 entries
# 2025-08-06 20:43:20,184 - INFO - kolosal_automl.modules.engine.jit_compiler - JIT compiler initialized with Numba support
# 2025-08-06 20:43:20,185 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - JIT compiler enabled for inference optimization
# 2025-08-06 20:43:20,184 - INFO - kolosal_automl.modules.engine.jit_compiler - JIT compiler initialized with Numba support
# 2025-08-06 20:43:20,185 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - JIT compiler enabled for inference optimization
# d:\Works\Genta\codes\automl_tutorial\kolosal_automl\modules\engine\mixed_precision.py:183: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.torch_scaler = GradScaler(
# d:\Works\Genta\codes\automl_tutorial\.venv\lib\site-packages\torch\amp\grad_scaler.py:132: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn(
# 2025-08-06 20:43:21,510 - INFO - kolosal_automl.modules.engine.mixed_precision - PyTorch AMP scaler initialized
# 2025-08-06 20:43:21,511 - INFO - kolosal_automl.modules.engine.mixed_precision - Mixed precision enabled
# 2025-08-06 20:43:21,512 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Mixed precision enabled for inference
# 2025-08-06 20:43:21,513 - INFO - kolosal_automl.modules.engine.streaming_pipeline - Streaming pipeline initialized with chunk_size=1000, parallel=True, distributed=False
# 2025-08-06 20:43:21,513 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Streaming pipeline available for batch inference
# 2025-08-06 20:43:21,515 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Resource monitoring started
# 2025-08-06 20:43:21,516 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Inference engine initialized with model version 1.0
# 2025-08-06 20:43:21,516 - INFO - MLTrainingEngine - Inference engine initialized
# 2025-08-06 20:43:21,517 - INFO - MLTrainingEngine - Model monitoring initialized
# 2025-08-06 20:43:21,517 - INFO - MLTrainingEngine - Optimization components disabled for fast initialization
# 2025-08-06 20:43:21,519 - INFO - MLTrainingEngine - ML Training Engine v0.1.4 initialized with task type: TaskType.REGRESSION
# d:\Works\Genta\codes\automl_tutorial\kolosal_automl\modules\engine\mixed_precision.py:183: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.torch_scaler = GradScaler(
# d:\Works\Genta\codes\automl_tutorial\.venv\lib\site-packages\torch\amp\grad_scaler.py:132: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn(
# 2025-08-06 20:43:21,510 - INFO - kolosal_automl.modules.engine.mixed_precision - PyTorch AMP scaler initialized
# 2025-08-06 20:43:21,511 - INFO - kolosal_automl.modules.engine.mixed_precision - Mixed precision enabled
# 2025-08-06 20:43:21,512 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Mixed precision enabled for inference
# 2025-08-06 20:43:21,513 - INFO - kolosal_automl.modules.engine.streaming_pipeline - Streaming pipeline initialized with chunk_size=1000, parallel=True, distributed=False
# 2025-08-06 20:43:21,513 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Streaming pipeline available for batch inference
# 2025-08-06 20:43:21,515 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Resource monitoring started
# 2025-08-06 20:43:21,516 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Inference engine initialized with model version 1.0
# 2025-08-06 20:43:21,516 - INFO - MLTrainingEngine - Inference engine initialized
# 2025-08-06 20:43:21,517 - INFO - MLTrainingEngine - Model monitoring initialized
# 2025-08-06 20:43:21,517 - INFO - MLTrainingEngine - Optimization components disabled for fast initialization
# 2025-08-06 20:43:21,519 - INFO - MLTrainingEngine - ML Training Engine v0.1.4 initialized with task type: TaskType.REGRESSION
# 2025-08-06 20:43:21,616 - INFO - MLTrainingEngine - Model types registered for auto discovery
# 2025-08-06 20:43:21,623 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - CPU usage (100.3%) above threshold, enabling throttling
# 2025-08-06 20:43:21,616 - INFO - MLTrainingEngine - Model types registered for auto discovery
# 2025-08-06 20:43:21,623 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - CPU usage (100.3%) above threshold, enabling throttling
# 2025-08-06 20:43:31,744 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - CPU usage (0.0%) below threshold, disabling throttling

# %% [markdown]
# # 🧪 Synthetic Dataset Generation
#
# To test our AutoML pipeline, we create a clean, synthetic dataset for regression modeling.
#
# ### Details
# - **Method**: `make_regression` from scikit-learn.
# - **Size**: 1,000 samples × 20 features.
# - **Noise**: Low (0.1), ensuring the model learns clear patterns.
#
# ### Outcome
# - `X`: Feature matrix (1000 × 20)
# - `y`: Target vector (1000,)

# %%
from sklearn.datasets import make_regression

data = make_regression(n_samples=1000, n_features=20, noise=0.1)
X, y= data

# %% [markdown]
# # 🚀 Model Training Execution
#
# With the dataset and engine ready, we now execute the automated training workflow.
#
# ### What Happens Under the Hood
# - Preprocessing: Scaling, transformation, or encoding (if needed)
# - Model Selection: Tries multiple regression models and tunes them
# - Training: Uses the best model and trains with optimal config
# - Evaluation: Computes metrics (e.g., MAE, RMSE) internally
#
# ### Outcome
# An optimized regression model is trained and stored in `training_engine`, ready for evaluation and prediction.

# %%
training_engine.train_model(X, y, model_name="my_model")
# Out:
# 2025-08-06 20:43:21,744 - INFO - MLTrainingEngine - Initialized random_forest model for regression
# 2025-08-06 20:43:21,745 - INFO - Experiment_1754487798 - Started experiment 1754487798
# 2025-08-06 20:43:21,746 - INFO - Experiment_1754487798 - Configuration:
# {
#   "task_type": "regression",
#   "random_state": 42,
#   "n_jobs": 18,
#   "verbose": 0,
#   "cv_folds": 5,
#   "test_size": 0.2,
#   "stratify": true,
#   "optimization_strategy": "hyper_optimization_x",
#   "optimization_iterations": 75,
#   "optimization_timeout": null,
#   "early_stopping": true,
#   "early_stopping_rounds": 10,
#   "early_stopping_metric": null,
#   "feature_selection": false,
#   "feature_selection_method": "mutual_info",
#   "feature_selection_k": null,
#   "feature_importance_threshold": 0.01,
#   "model_path": "model_registry\\training_models",
#   "model_registry_url": null,
#   "auto_version_models": true,
#   "experiment_tracking": true,
#   "experiment_tracking_platform": "mlflow",
#   "experiment_tracking_config": {},
#   "use_intel_optimization": false,
#   "use_gpu": false,
#   "gpu_memory_fraction": 0.0,
#   "memory_optimization": false,
#   "enable_distributed": false,
#   "distributed_strategy": "mirrored",
#   "distributed_config": {},
#   "checkpointing": false,
#   "checkpoint_interval": 10,
#   "checkpoint_path": "checkpoints\\training_checkpoints",
#   "enable_pruning": false,
#   "auto_ml": "basic",
#   "auto_ml_time_budget": null,
#   "ensemble_models": true,
#   "ensemble_method": "voting",
#   "ensemble_size": 3,
#   "hyperparameter_tuning_cv": true,
#   "model_selection_criteria": "accuracy",
#   "auto_save": true,
#   "auto_save_on_shutdown": true,
#   "save_state_on_shutdown": false,
#   "load_best_model_after_train": true,
#   "enable_quantization": false,
#   "enable_model_compression": false,
#   "compression_method": "pruning",
#   "compute_permutation_importance": false,
#   "generate_feature_importance_report": true,
#   "generate_model_summary": true,
#   "generate_prediction_explanations": false,
#   "enable_model_export": true,
#   "export_formats": [
#     "sklearn"
#   ],
#   "auto_deploy": false,
#   "deployment_platform": null,
#   "deployment_config": {},
#   "log_level": "INFO",
#   "debug_mode": false,
#   "enable_telemetry": false,
#   "backend": "sklearn",
#   "enable_data_validation": true,
#   "enable_security": false,
#   "security_config": {},
#   "metadata": {
#     "device_info": {
#       "cpu_count_physical": 14,
#       "cpu_count_logical": 20,
#       "total_memory_gb": 63.668304443359375,
#       "is_intel_cpu": true,
#       "has_gpu": false
#     },
#     "optimizer_settings": {
#       "optimization_mode": "performance",
#       "environment": "cloud",
#       "workload_type": "mixed",
#       "auto_tune_optimizer": true
#     }
#   },
#   "optimization_metric": "accuracy",
#   "preprocessing_config": {
#     "normalization": "none",
#     "robust_percentiles": [
#       25.0,
#       75.0
#     ],
#     "handle_nan": true,
#     "handle_inf": true,
#     "nan_strategy": "mean",
#     "nan_fill_value": 0.0,
#     "inf_strategy": "max_value",
#     "pos_inf_fill_value": 10000000000.0,
#     "neg_inf_fill_value": -10000000000.0,
#     "inf_buffer": 1.0,
#     "copy_X": true,
#     "detect_outliers": false,
#     "outlier_method": "iqr",
#     "outlier_handling": "clip",
#     "outlier_contamination": 0.05,
#     "outlier_iqr_multiplier": 1.5,
#     "outlier_zscore_threshold": 3.0,
#     "outlier_percentiles": [
#       1.0,
#       99.0
#     ],
#     "feature_outlier_mask": [],
#     "clip_values": false,
#     "clip_min": -10000000000.0,
#     "clip_max": 10000000000.0,
#     "scale_shift": false,
#     "scale_offset": 0.0,
#     "custom_center_func": null,
#     "custom_scale_func": null,
#     "custom_normalization_fn": null,
#     "custom_transform_fn": null,
#     "custom_inverse_fn": null,
#     "categorical_encoding": "one_hot",
#     "categorical_max_categories": 20,
#     "auto_feature_selection": true,
#     "numeric_transformations": [],
#     "text_vectorization": "tfidf",
#     "text_max_features": 5000,
#     "dimension_reduction": null,
#     "dimension_reduction_target": null,
#     "datetime_features": true,
#     "image_preprocessing": {},
#     "handle_imbalance": false,
#     "imbalance_strategy": "smote",
#     "feature_interaction": false,
#     "feature_interaction_max": 10,
#     "custom_transformers": [],
#     "transformation_pipeline": [],
#     "parallel_processing": true,
#     "cache_preprocessing": true,
#     "verbosity": 1,
#     "enable_input_validation": false,
#     "input_size_limit": null,
#     "n_jobs": 10,
#     "chunk_size": null,
#     "cache_enabled": true,
#     "cache_size": 128,
#     "dtype": "<class 'numpy.float64'>",
#     "epsilon": 1e-10,
#     "debug_mode": false,
#     "version": "0.1.4"
#   },
#   "batch_processing_config": {
#     "initial_batch_size": 281,
#     "min_batch_size": 70,
#     "max_batch_size": 281,
#     "max_queue_size": 1124,
#     "batch_timeout": 0.01,
#     "num_workers": 18,
#     "adaptive_batching": true,
#     "batch_allocation_strategy": "dynamic",
#     "enable_priority_queue": true,
#     "priority_levels": 3,
#     "enable_monitoring": false,
#     "monitoring_interval": 2.0,
#     "enable_memory_optimization": false,
#     "enable_prefetching": true,
#     "prefetch_batches": 2,
#     "checkpoint_batches": false,
#     "checkpoint_interval": 100,
#     "error_handling": "retry",
#     "max_retries": 3,
#     "retry_delay": 0.5,
#     "distributed_processing": false,
#     "resource_allocation": {},
#     "item_timeout": 10.0,
#     "min_batch_interval": 0.0,
#     "processing_strategy": "ADAPTIVE",
#     "enable_adaptive_batching": true,
#     "reduce_batch_on_failure": true,
#     "max_batch_memory_mb": null,
#     "gc_batch_threshold": 32,
#     "monitoring_window": 100,
#     "max_workers": 18,
#     "enable_health_monitoring": true,
#     "health_check_interval": 5.0,
#     "memory_warning_threshold": 70.0,
#     "memory_critical_threshold": 85.0,
#     "queue_warning_threshold": 100,
#     "queue_critical_threshold": 500,
#     "debug_mode": false
#   },
#   "inference_config": {
#     "enable_intel_optimization": false,
#     "enable_batching": true,
#     "enable_quantization": true,
#     "model_cache_size": 5,
#     "model_precision": "fp32",
#     "max_batch_size": 64,
#     "timeout_ms": 100,
#     "enable_jit": true,
#     "enable_onnx": false,
#     "onnx_opset": 15,
#     "enable_tensorrt": false,
#     "runtime_optimization": true,
#     "fallback_to_cpu": true,
#     "thread_count": 20,
#     "warmup": true,
#     "warmup_iterations": 10,
#     "profiling": false,
#     "batching_strategy": "dynamic",
#     "output_streaming": false,
#     "debug_mode": false,
#     "memory_growth": true,
#     "custom_ops": [],
#     "use_platform_accelerator": true,
#     "platform_accelerator_config": {},
#     "model_version": "1.0",
#     "num_threads": 4,
#     "set_cpu_affinity": false,
#     "enable_model_quantization": false,
#     "enable_input_quantization": false,
#     "quantization_dtype": "int8",
#     "enable_request_deduplication": true,
#     "max_cache_entries": 1000,
#     "cache_ttl_seconds": 300,
#     "monitoring_window": 100,
#     "enable_monitoring": true,
#     "monitoring_interval": 10.0,
#     "throttle_on_high_cpu": true,
#     "cpu_threshold_percent": 90.0,
#     "memory_high_watermark_mb": 1024.0,
#     "memory_limit_gb": null,
#     "batch_timeout": 0.1,
#     "max_concurrent_requests": 8,
#     "initial_batch_size": 16,
#     "min_batch_size": 1,
#     "enable_adaptive_batching": true,
#     "enable_memory_optimization": true,
#     "enable_feature_scaling": false,
#     "enable_warmup": true,
#     "enable_quantization_aware_inference": false,
#     "enable_throttling": true,
#     "enable_jit_compilation": true,
#     "enable_mixed_precision": true,
#     "enable_streaming": true,
#     "streaming_batch_size": 1000,
#     "optimization_mode": "balanced",
#     "enable_fp16_optimization": false,
#     "enable_compiler_optimization": true,
#     "threadpoolctl_available": false,
#     "onnx_available": false,
#     "treelite_available": false,
#     "quantization_config": {
#       "quantization_type": "int8",
#       "quantization_mode": "dynamic",
#       "per_channel": false,
#       "symmetric": true,
#       "enable_cache": true,
#       "cache_size": 256,
#       "calibration_samples": 100,
#       "calibration_method": "percentile",
#       "percentile": 99.99,
#       "skip_layers": [],
#       "quantize_weights_only": false,
#       "quantize_activations": true,
#       "weight_bits": 8,
#       "activation_bits": 8,
#       "quantize_bias": true,
#       "bias_bits": 32,
#       "enable_mixed_precision": false,
#       "mixed_precision_layers": [],
#       "optimize_for": "performance",
#       "custom_quantization_config": {},
#       "enable_requantization": false,
#       "requantization_threshold": 0.1,
#       "use_percentile": false,
#       "min_percentile": 0.1,
#       "max_percentile": 99.9,
#       "error_on_nan": false,
#       "error_on_inf": false,
#       "outlier_threshold": null,
#       "num_bits": 8,
#       "optimize_memory": true,
#       "buffer_size": 0
#     },
#     "batch_processor_config": {
#       "initial_batch_size": 16,
#       "min_batch_size": 1,
#       "max_batch_size": 64,
#       "max_queue_size": 16,
#       "batch_timeout": 0.1,
#       "num_workers": 4,
#       "adaptive_batching": true,
#       "batch_allocation_strategy": "dynamic",
#       "enable_priority_queue": true,
#       "priority_levels": 3,
#       "enable_monitoring": true,
#       "monitoring_interval": 2.0,
#       "enable_memory_optimization": true,
#       "enable_prefetching": true,
#       "prefetch_batches": 2,
#       "checkpoint_batches": false,
#       "checkpoint_interval": 100,
#       "error_handling": "retry",
#       "max_retries": 3,
#       "retry_delay": 0.5,
#       "distributed_processing": false,
#       "resource_allocation": {},
#       "item_timeout": 10.0,
#       "min_batch_interval": 0.0,
#       "processing_strategy": "ADAPTIVE",
#       "enable_adaptive_batching": true,
#       "reduce_batch_on_failure": true,
#       "max_batch_memory_mb": null,
#       "gc_batch_threshold": 32,
#       "monitoring_window": 100,
#       "max_workers": 4,
#       "enable_health_monitoring": true,
#       "health_check_interval": 5.0,
#       "memory_warning_threshold": 70.0,
#       "memory_critical_threshold": 85.0,
#       "queue_warning_threshold": 100,
#       "queue_critical_threshold": 500,
#       "debug_mode": false
#     }
#   },
#   "quantization_config": {
#     "quantization_type": "int8",
#     "quantization_mode": "dynamic_per_batch",
#     "per_channel": false,
#     "symmetric": true,
#     "enable_cache": true,
#     "cache_size": 256,
#     "calibration_samples": 100,
#     "calibration_method": "percentile",
#     "percentile": 99.99,
#     "skip_layers": [],
#     "quantize_weights_only": false,
#     "quantize_activations": true,
#     "weight_bits": 8,
#     "activation_bits": 8,
#     "quantize_bias": true,
#     "bias_bits": 32,
#     "enable_mixed_precision": false,
#     "mixed_precision_layers": [],
#     "optimize_for": "performance",
#     "custom_quantization_config": {},
#     "enable_requantization": false,
#     "requantization_threshold": 0.1,
#     "use_percentile": false,
#     "min_percentile": 0.1,
#     "max_percentile": 99.9,
#     "error_on_nan": false,
#     "error_on_inf": false,
#     "outlier_threshold": null,
#     "num_bits": 8,
#     "optimize_memory": true,
#     "buffer_size": 0
#   },
#   "explainability_config": {
#     "enable_explainability": false,
#     "methods": [
#       "shap",
#       "feature_importance"
#     ],
#     "default_method": "shap",
#     "shap_algorithm": "auto",
#     "shap_samples": 100,
#     "lime_samples": 1000,
#     "feature_importance_permutations": 10,
#     "partial_dependence_features": [],
#     "partial_dependence_grid_points": 20,
#     "eli5_permutation_samples": 100,
#     "generate_summary": true,
#     "generate_plots": true,
#     "explainability_report_format": "html",
#     "store_explanations": true,
#     "explanation_cache_size": 100,
#     "enable_counterfactuals": false,
#     "counterfactual_method": "dice",
#     "custom_explainers": []
#   },
#   "monitoring_config": {
#     "enable_monitoring": true,
#     "drift_detection": true,
#     "drift_detection_method": "ks_test",
#     "drift_threshold": 0.05,
#     "drift_check_interval": "1h",
#     "monitoring_interval": "1h",
#     "performance_tracking": true,
#     "performance_metrics": [
#       "accuracy",
#       "latency"
#     ],
#     "performance_threshold": 0.1,
#     "alert_on_drift": false,
#     "alert_on_performance_drop": true,
#     "alert_channels": [
#       "log"
#     ],
#     "monitoring_report_interval": "1d",
#     "data_sampling_rate": 1.0,
#     "store_predictions": true,
#     "prediction_store_size": 10000,
#     "enable_auto_retraining": false,
#     "retraining_trigger_drift_threshold": 0.1,
#     "retraining_trigger_performance_drop": 0.05,
#     "export_metrics": false,
#     "metrics_export_format": "prometheus",
#     "custom_monitors": []
#   }
# }
# 2025-08-06 20:43:21,747 - INFO - Experiment_1754487798 - Model: {'model_type': 'random_forest', 'model_class': 'sklearn.ensemble._forest.RandomForestRegressor', 'task_type': 'regression'}
# 2025-08-06 20:43:21,748 - INFO - MLTrainingEngine - Test data split: 200 test samples reserved for final evaluation
# 2025-08-06 20:43:21,745 - INFO - Experiment_1754487798 - Started experiment 1754487798
# 2025-08-06 20:43:21,746 - INFO - Experiment_1754487798 - Configuration:
# {
#   "task_type": "regression",
#   "random_state": 42,
#   "n_jobs": 18,
#   "verbose": 0,
#   "cv_folds": 5,
#   "test_size": 0.2,
#   "stratify": true,
#   "optimization_strategy": "hyper_optimization_x",
#   "optimization_iterations": 75,
#   "optimization_timeout": null,
#   "early_stopping": true,
#   "early_stopping_rounds": 10,
#   "early_stopping_metric": null,
#   "feature_selection": false,
#   "feature_selection_method": "mutual_info",
#   "feature_selection_k": null,
#   "feature_importance_threshold": 0.01,
#   "model_path": "model_registry\\training_models",
#   "model_registry_url": null,
#   "auto_version_models": true,
#   "experiment_tracking": true,
#   "experiment_tracking_platform": "mlflow",
#   "experiment_tracking_config": {},
#   "use_intel_optimization": false,
#   "use_gpu": false,
#   "gpu_memory_fraction": 0.0,
#   "memory_optimization": false,
#   "enable_distributed": false,
#   "distributed_strategy": "mirrored",
#   "distributed_config": {},
#   "checkpointing": false,
#   "checkpoint_interval": 10,
#   "checkpoint_path": "checkpoints\\training_checkpoints",
#   "enable_pruning": false,
#   "auto_ml": "basic",
#   "auto_ml_time_budget": null,
#   "ensemble_models": true,
#   "ensemble_method": "voting",
#   "ensemble_size": 3,
#   "hyperparameter_tuning_cv": true,
#   "model_selection_criteria": "accuracy",
#   "auto_save": true,
#   "auto_save_on_shutdown": true,
#   "save_state_on_shutdown": false,
#   "load_best_model_after_train": true,
#   "enable_quantization": false,
#   "enable_model_compression": false,
#   "compression_method": "pruning",
#   "compute_permutation_importance": false,
#   "generate_feature_importance_report": true,
#   "generate_model_summary": true,
#   "generate_prediction_explanations": false,
#   "enable_model_export": true,
#   "export_formats": [
#     "sklearn"
#   ],
#   "auto_deploy": false,
#   "deployment_platform": null,
#   "deployment_config": {},
#   "log_level": "INFO",
#   "debug_mode": false,
#   "enable_telemetry": false,
#   "backend": "sklearn",
#   "enable_data_validation": true,
#   "enable_security": false,
#   "security_config": {},
#   "metadata": {
#     "device_info": {
#       "cpu_count_physical": 14,
#       "cpu_count_logical": 20,
#       "total_memory_gb": 63.668304443359375,
#       "is_intel_cpu": true,
#       "has_gpu": false
#     },
#     "optimizer_settings": {
#       "optimization_mode": "performance",
#       "environment": "cloud",
#       "workload_type": "mixed",
#       "auto_tune_optimizer": true
#     }
#   },
#   "optimization_metric": "accuracy",
#   "preprocessing_config": {
#     "normalization": "none",
#     "robust_percentiles": [
#       25.0,
#       75.0
#     ],
#     "handle_nan": true,
#     "handle_inf": true,
#     "nan_strategy": "mean",
#     "nan_fill_value": 0.0,
#     "inf_strategy": "max_value",
#     "pos_inf_fill_value": 10000000000.0,
#     "neg_inf_fill_value": -10000000000.0,
#     "inf_buffer": 1.0,
#     "copy_X": true,
#     "detect_outliers": false,
#     "outlier_method": "iqr",
#     "outlier_handling": "clip",
#     "outlier_contamination": 0.05,
#     "outlier_iqr_multiplier": 1.5,
#     "outlier_zscore_threshold": 3.0,
#     "outlier_percentiles": [
#       1.0,
#       99.0
#     ],
#     "feature_outlier_mask": [],
#     "clip_values": false,
#     "clip_min": -10000000000.0,
#     "clip_max": 10000000000.0,
#     "scale_shift": false,
#     "scale_offset": 0.0,
#     "custom_center_func": null,
#     "custom_scale_func": null,
#     "custom_normalization_fn": null,
#     "custom_transform_fn": null,
#     "custom_inverse_fn": null,
#     "categorical_encoding": "one_hot",
#     "categorical_max_categories": 20,
#     "auto_feature_selection": true,
#     "numeric_transformations": [],
#     "text_vectorization": "tfidf",
#     "text_max_features": 5000,
#     "dimension_reduction": null,
#     "dimension_reduction_target": null,
#     "datetime_features": true,
#     "image_preprocessing": {},
#     "handle_imbalance": false,
#     "imbalance_strategy": "smote",
#     "feature_interaction": false,
#     "feature_interaction_max": 10,
#     "custom_transformers": [],
#     "transformation_pipeline": [],
#     "parallel_processing": true,
#     "cache_preprocessing": true,
#     "verbosity": 1,
#     "enable_input_validation": false,
#     "input_size_limit": null,
#     "n_jobs": 10,
#     "chunk_size": null,
#     "cache_enabled": true,
#     "cache_size": 128,
#     "dtype": "<class 'numpy.float64'>",
#     "epsilon": 1e-10,
#     "debug_mode": false,
#     "version": "0.1.4"
#   },
#   "batch_processing_config": {
#     "initial_batch_size": 281,
#     "min_batch_size": 70,
#     "max_batch_size": 281,
#     "max_queue_size": 1124,
#     "batch_timeout": 0.01,
#     "num_workers": 18,
#     "adaptive_batching": true,
#     "batch_allocation_strategy": "dynamic",
#     "enable_priority_queue": true,
#     "priority_levels": 3,
#     "enable_monitoring": false,
#     "monitoring_interval": 2.0,
#     "enable_memory_optimization": false,
#     "enable_prefetching": true,
#     "prefetch_batches": 2,
#     "checkpoint_batches": false,
#     "checkpoint_interval": 100,
#     "error_handling": "retry",
#     "max_retries": 3,
#     "retry_delay": 0.5,
#     "distributed_processing": false,
#     "resource_allocation": {},
#     "item_timeout": 10.0,
#     "min_batch_interval": 0.0,
#     "processing_strategy": "ADAPTIVE",
#     "enable_adaptive_batching": true,
#     "reduce_batch_on_failure": true,
#     "max_batch_memory_mb": null,
#     "gc_batch_threshold": 32,
#     "monitoring_window": 100,
#     "max_workers": 18,
#     "enable_health_monitoring": true,
#     "health_check_interval": 5.0,
#     "memory_warning_threshold": 70.0,
#     "memory_critical_threshold": 85.0,
#     "queue_warning_threshold": 100,
#     "queue_critical_threshold": 500,
#     "debug_mode": false
#   },
#   "inference_config": {
#     "enable_intel_optimization": false,
#     "enable_batching": true,
#     "enable_quantization": true,
#     "model_cache_size": 5,
#     "model_precision": "fp32",
#     "max_batch_size": 64,
#     "timeout_ms": 100,
#     "enable_jit": true,
#     "enable_onnx": false,
#     "onnx_opset": 15,
#     "enable_tensorrt": false,
#     "runtime_optimization": true,
#     "fallback_to_cpu": true,
#     "thread_count": 20,
#     "warmup": true,
#     "warmup_iterations": 10,
#     "profiling": false,
#     "batching_strategy": "dynamic",
#     "output_streaming": false,
#     "debug_mode": false,
#     "memory_growth": true,
#     "custom_ops": [],
#     "use_platform_accelerator": true,
#     "platform_accelerator_config": {},
#     "model_version": "1.0",
#     "num_threads": 4,
#     "set_cpu_affinity": false,
#     "enable_model_quantization": false,
#     "enable_input_quantization": false,
#     "quantization_dtype": "int8",
#     "enable_request_deduplication": true,
#     "max_cache_entries": 1000,
#     "cache_ttl_seconds": 300,
#     "monitoring_window": 100,
#     "enable_monitoring": true,
#     "monitoring_interval": 10.0,
#     "throttle_on_high_cpu": true,
#     "cpu_threshold_percent": 90.0,
#     "memory_high_watermark_mb": 1024.0,
#     "memory_limit_gb": null,
#     "batch_timeout": 0.1,
#     "max_concurrent_requests": 8,
#     "initial_batch_size": 16,
#     "min_batch_size": 1,
#     "enable_adaptive_batching": true,
#     "enable_memory_optimization": true,
#     "enable_feature_scaling": false,
#     "enable_warmup": true,
#     "enable_quantization_aware_inference": false,
#     "enable_throttling": true,
#     "enable_jit_compilation": true,
#     "enable_mixed_precision": true,
#     "enable_streaming": true,
#     "streaming_batch_size": 1000,
#     "optimization_mode": "balanced",
#     "enable_fp16_optimization": false,
#     "enable_compiler_optimization": true,
#     "threadpoolctl_available": false,
#     "onnx_available": false,
#     "treelite_available": false,
#     "quantization_config": {
#       "quantization_type": "int8",
#       "quantization_mode": "dynamic",
#       "per_channel": false,
#       "symmetric": true,
#       "enable_cache": true,
#       "cache_size": 256,
#       "calibration_samples": 100,
#       "calibration_method": "percentile",
#       "percentile": 99.99,
#       "skip_layers": [],
#       "quantize_weights_only": false,
#       "quantize_activations": true,
#       "weight_bits": 8,
#       "activation_bits": 8,
#       "quantize_bias": true,
#       "bias_bits": 32,
#       "enable_mixed_precision": false,
#       "mixed_precision_layers": [],
#       "optimize_for": "performance",
#       "custom_quantization_config": {},
#       "enable_requantization": false,
#       "requantization_threshold": 0.1,
#       "use_percentile": false,
#       "min_percentile": 0.1,
#       "max_percentile": 99.9,
#       "error_on_nan": false,
#       "error_on_inf": false,
#       "outlier_threshold": null,
#       "num_bits": 8,
#       "optimize_memory": true,
#       "buffer_size": 0
#     },
#     "batch_processor_config": {
#       "initial_batch_size": 16,
#       "min_batch_size": 1,
#       "max_batch_size": 64,
#       "max_queue_size": 16,
#       "batch_timeout": 0.1,
#       "num_workers": 4,
#       "adaptive_batching": true,
#       "batch_allocation_strategy": "dynamic",
#       "enable_priority_queue": true,
#       "priority_levels": 3,
#       "enable_monitoring": true,
#       "monitoring_interval": 2.0,
#       "enable_memory_optimization": true,
#       "enable_prefetching": true,
#       "prefetch_batches": 2,
#       "checkpoint_batches": false,
#       "checkpoint_interval": 100,
#       "error_handling": "retry",
#       "max_retries": 3,
#       "retry_delay": 0.5,
#       "distributed_processing": false,
#       "resource_allocation": {},
#       "item_timeout": 10.0,
#       "min_batch_interval": 0.0,
#       "processing_strategy": "ADAPTIVE",
#       "enable_adaptive_batching": true,
#       "reduce_batch_on_failure": true,
#       "max_batch_memory_mb": null,
#       "gc_batch_threshold": 32,
#       "monitoring_window": 100,
#       "max_workers": 4,
#       "enable_health_monitoring": true,
#       "health_check_interval": 5.0,
#       "memory_warning_threshold": 70.0,
#       "memory_critical_threshold": 85.0,
#       "queue_warning_threshold": 100,
#       "queue_critical_threshold": 500,
#       "debug_mode": false
#     }
#   },
#   "quantization_config": {
#     "quantization_type": "int8",
#     "quantization_mode": "dynamic_per_batch",
#     "per_channel": false,
#     "symmetric": true,
#     "enable_cache": true,
#     "cache_size": 256,
#     "calibration_samples": 100,
#     "calibration_method": "percentile",
#     "percentile": 99.99,
#     "skip_layers": [],
#     "quantize_weights_only": false,
#     "quantize_activations": true,
#     "weight_bits": 8,
#     "activation_bits": 8,
#     "quantize_bias": true,
#     "bias_bits": 32,
#     "enable_mixed_precision": false,
#     "mixed_precision_layers": [],
#     "optimize_for": "performance",
#     "custom_quantization_config": {},
#     "enable_requantization": false,
#     "requantization_threshold": 0.1,
#     "use_percentile": false,
#     "min_percentile": 0.1,
#     "max_percentile": 99.9,
#     "error_on_nan": false,
#     "error_on_inf": false,
#     "outlier_threshold": null,
#     "num_bits": 8,
#     "optimize_memory": true,
#     "buffer_size": 0
#   },
#   "explainability_config": {
#     "enable_explainability": false,
#     "methods": [
#       "shap",
#       "feature_importance"
#     ],
#     "default_method": "shap",
#     "shap_algorithm": "auto",
#     "shap_samples": 100,
#     "lime_samples": 1000,
#     "feature_importance_permutations": 10,
#     "partial_dependence_features": [],
#     "partial_dependence_grid_points": 20,
#     "eli5_permutation_samples": 100,
#     "generate_summary": true,
#     "generate_plots": true,
#     "explainability_report_format": "html",
#     "store_explanations": true,
#     "explanation_cache_size": 100,
#     "enable_counterfactuals": false,
#     "counterfactual_method": "dice",
#     "custom_explainers": []
#   },
#   "monitoring_config": {
#     "enable_monitoring": true,
#     "drift_detection": true,
#     "drift_detection_method": "ks_test",
#     "drift_threshold": 0.05,
#     "drift_check_interval": "1h",
#     "monitoring_interval": "1h",
#     "performance_tracking": true,
#     "performance_metrics": [
#       "accuracy",
#       "latency"
#     ],
#     "performance_threshold": 0.1,
#     "alert_on_drift": false,
#     "alert_on_performance_drop": true,
#     "alert_channels": [
#       "log"
#     ],
#     "monitoring_report_interval": "1d",
#     "data_sampling_rate": 1.0,
#     "store_predictions": true,
#     "prediction_store_size": 10000,
#     "enable_auto_retraining": false,
#     "retraining_trigger_drift_threshold": 0.1,
#     "retraining_trigger_performance_drop": 0.05,
#     "export_metrics": false,
#     "metrics_export_format": "prometheus",
#     "custom_monitors": []
#   }
# }
# 2025-08-06 20:43:21,747 - INFO - Experiment_1754487798 - Model: {'model_type': 'random_forest', 'model_class': 'sklearn.ensemble._forest.RandomForestRegressor', 'task_type': 'regression'}
# 2025-08-06 20:43:21,748 - INFO - MLTrainingEngine - Test data split: 200 test samples reserved for final evaluation
# 2025-08-06 20:43:21,749 - INFO - MLTrainingEngine - Data split: 640 training samples, 160 validation samples, 200 test samples
# 2025-08-06 20:43:21,966 - INFO - MLTrainingEngine - Starting hyperparameter optimization with OptimizationStrategy.HYPERX
# 2025-08-06 20:43:21,966 - INFO - MLTrainingEngine - Using HyperOptX with 15 iterations (reduced from 75 for performance)
# 2025-08-06 20:43:21,749 - INFO - MLTrainingEngine - Data split: 640 training samples, 160 validation samples, 200 test samples
# 2025-08-06 20:43:21,966 - INFO - MLTrainingEngine - Starting hyperparameter optimization with OptimizationStrategy.HYPERX
# 2025-08-06 20:43:21,966 - INFO - MLTrainingEngine - Using HyperOptX with 15 iterations (reduced from 75 for performance)
# 2025-08-06 20:43:21,978 - INFO - Experiment_1754487798 - Metrics for optimization_setup: {'param_combinations': 'grid', 'cv_folds': 5, 'scoring': 'accuracy'}
# 2025-08-06 20:43:21,978 - INFO - Experiment_1754487798 - Metrics for optimization_setup: {'param_combinations': 'grid', 'cv_folds': 5, 'scoring': 'accuracy'}
# 2025-08-06 20:43:44,401 - INFO - Experiment_1754487798 - Metrics for optimization: {'mean_cv_score': -inf, 'std_cv_score': 0.0, 'optimization_time': 22.42220640182495}
# 2025-08-06 20:43:44,402 - INFO - MLTrainingEngine - Best CV score: -inf ± 0.0000
# 2025-08-06 20:43:44,403 - INFO - MLTrainingEngine - Best parameters: {'estimator': RandomForestRegressor(), 'param_space': {'n_estimators': [100, 200], 'max_depth': [None, 10], 'min_samples_split': [2]}, 'max_iter': 15, 'cv': 5, 'scoring': 'accuracy', 'random_state': 42, 'n_jobs': -1, 'verbose': 0, 'maximize': True, 'time_budget': None, 'ensemble_surrogate': True, 'transfer_learning': True, 'optimization_strategy': 'auto', 'early_stopping': True, 'meta_learning': True, 'constraint_handling': 'auto', 'estimator__bootstrap': True, 'estimator__ccp_alpha': 0.0, 'estimator__criterion': 'squared_error', 'estimator__max_depth': None, 'estimator__max_features': 1.0, 'estimator__max_leaf_nodes': None, 'estimator__max_samples': None, 'estimator__min_impurity_decrease': 0.0, 'estimator__min_samples_leaf': 1, 'estimator__min_samples_split': 2, 'estimator__min_weight_fraction_leaf': 0.0, 'estimator__monotonic_cst': None, 'estimator__n_estimators': 100, 'estimator__n_jobs': None, 'estimator__oob_score': False, 'estimator__random_state': None, 'estimator__verbose': 0, 'estimator__warm_start': False}
# 2025-08-06 20:43:44,401 - INFO - Experiment_1754487798 - Metrics for optimization: {'mean_cv_score': -inf, 'std_cv_score': 0.0, 'optimization_time': 22.42220640182495}
# 2025-08-06 20:43:44,402 - INFO - MLTrainingEngine - Best CV score: -inf ± 0.0000
# 2025-08-06 20:43:44,403 - INFO - MLTrainingEngine - Best parameters: {'estimator': RandomForestRegressor(), 'param_space': {'n_estimators': [100, 200], 'max_depth': [None, 10], 'min_samples_split': [2]}, 'max_iter': 15, 'cv': 5, 'scoring': 'accuracy', 'random_state': 42, 'n_jobs': -1, 'verbose': 0, 'maximize': True, 'time_budget': None, 'ensemble_surrogate': True, 'transfer_learning': True, 'optimization_strategy': 'auto', 'early_stopping': True, 'meta_learning': True, 'constraint_handling': 'auto', 'estimator__bootstrap': True, 'estimator__ccp_alpha': 0.0, 'estimator__criterion': 'squared_error', 'estimator__max_depth': None, 'estimator__max_features': 1.0, 'estimator__max_leaf_nodes': None, 'estimator__max_samples': None, 'estimator__min_impurity_decrease': 0.0, 'estimator__min_samples_leaf': 1, 'estimator__min_samples_split': 2, 'estimator__min_weight_fraction_leaf': 0.0, 'estimator__monotonic_cst': None, 'estimator__n_estimators': 100, 'estimator__n_jobs': None, 'estimator__oob_score': False, 'estimator__random_state': None, 'estimator__verbose': 0, 'estimator__warm_start': False}
# 2025-08-06 20:43:44,503 - INFO - MLTrainingEngine - Evaluating model on validation data...
# 2025-08-06 20:43:44,510 - INFO - Experiment_1754487798 - Metrics for validation: {'mse': 3169.5485057476335, 'rmse': 56.29874337627469, 'mae': 44.107523348442086, 'r2': 0.8324192479979334}
# 2025-08-06 20:43:44,511 - INFO - MLTrainingEngine - Validation mse: 3169.5485
# 2025-08-06 20:43:44,511 - INFO - MLTrainingEngine - Validation rmse: 56.2987
# 2025-08-06 20:43:44,512 - INFO - MLTrainingEngine - Validation mae: 44.1075
# 2025-08-06 20:43:44,512 - INFO - MLTrainingEngine - Validation r2: 0.8324
# 2025-08-06 20:43:44,503 - INFO - MLTrainingEngine - Evaluating model on validation data...
# 2025-08-06 20:43:44,510 - INFO - Experiment_1754487798 - Metrics for validation: {'mse': 3169.5485057476335, 'rmse': 56.29874337627469, 'mae': 44.107523348442086, 'r2': 0.8324192479979334}
# 2025-08-06 20:43:44,511 - INFO - MLTrainingEngine - Validation mse: 3169.5485
# 2025-08-06 20:43:44,511 - INFO - MLTrainingEngine - Validation rmse: 56.2987
# 2025-08-06 20:43:44,512 - INFO - MLTrainingEngine - Validation mae: 44.1075
# 2025-08-06 20:43:44,512 - INFO - MLTrainingEngine - Validation r2: 0.8324
# 2025-08-06 20:43:44,615 - INFO - Experiment_1754487798 - Feature importance: {
#   "feature_6": 0.3109142669072764,
#   "feature_9": 0.2961490345268284,
#   "feature_19": 0.1637819348185699,
#   "feature_5": 0.0477189371004037,
#   "feature_18": 0.03481588132100913,
#   "feature_16": 0.025810772893366644,
#   "feature_13": 0.014153407757745436,
#   "feature_2": 0.012343736310051588,
#   "feature_1": 0.010634413807426715,
#   "feature_12": 0.00844024666503972
# }
# 2025-08-06 20:43:44,616 - INFO - MLTrainingEngine - Top 10 features by importance:
# 2025-08-06 20:43:44,616 - INFO - MLTrainingEngine -   feature_6: 0.3109
# 2025-08-06 20:43:44,617 - INFO - MLTrainingEngine -   feature_9: 0.2961
# 2025-08-06 20:43:44,618 - INFO - MLTrainingEngine -   feature_19: 0.1638
# 2025-08-06 20:43:44,618 - INFO - MLTrainingEngine -   feature_5: 0.0477
# 2025-08-06 20:43:44,619 - INFO - MLTrainingEngine -   feature_18: 0.0348
# 2025-08-06 20:43:44,619 - INFO - MLTrainingEngine -   feature_16: 0.0258
# 2025-08-06 20:43:44,619 - INFO - MLTrainingEngine -   feature_13: 0.0142
# 2025-08-06 20:43:44,619 - INFO - MLTrainingEngine -   feature_2: 0.0123
# 2025-08-06 20:43:44,619 - INFO - MLTrainingEngine -   feature_1: 0.0106
# 2025-08-06 20:43:44,615 - INFO - Experiment_1754487798 - Feature importance: {
#   "feature_6": 0.3109142669072764,
#   "feature_9": 0.2961490345268284,
#   "feature_19": 0.1637819348185699,
#   "feature_5": 0.0477189371004037,
#   "feature_18": 0.03481588132100913,
#   "feature_16": 0.025810772893366644,
#   "feature_13": 0.014153407757745436,
#   "feature_2": 0.012343736310051588,
#   "feature_1": 0.010634413807426715,
#   "feature_12": 0.00844024666503972
# }
# 2025-08-06 20:43:44,616 - INFO - MLTrainingEngine - Top 10 features by importance:
# 2025-08-06 20:43:44,616 - INFO - MLTrainingEngine -   feature_6: 0.3109
# 2025-08-06 20:43:44,617 - INFO - MLTrainingEngine -   feature_9: 0.2961
# 2025-08-06 20:43:44,618 - INFO - MLTrainingEngine -   feature_19: 0.1638
# 2025-08-06 20:43:44,618 - INFO - MLTrainingEngine -   feature_5: 0.0477
# 2025-08-06 20:43:44,619 - INFO - MLTrainingEngine -   feature_18: 0.0348
# 2025-08-06 20:43:44,619 - INFO - MLTrainingEngine -   feature_16: 0.0258
# 2025-08-06 20:43:44,619 - INFO - MLTrainingEngine -   feature_13: 0.0142
# 2025-08-06 20:43:44,619 - INFO - MLTrainingEngine -   feature_2: 0.0123
# 2025-08-06 20:43:44,619 - INFO - MLTrainingEngine -   feature_1: 0.0106
# 2025-08-06 20:43:44,620 - INFO - MLTrainingEngine -   feature_12: 0.0084
# 2025-08-06 20:43:44,717 - INFO - MLTrainingEngine - New best model: my_model with score 0.8324
# 2025-08-06 20:43:44,724 - INFO - MLTrainingEngine - Model 'my_model' saved to model_registry\training_models\my_model.pkl
# 2025-08-06 20:43:44,727 - INFO - Experiment_1754487798 - Experiment completed in 22.98 seconds
# 2025-08-06 20:43:44,620 - INFO - MLTrainingEngine -   feature_12: 0.0084
# 2025-08-06 20:43:44,717 - INFO - MLTrainingEngine - New best model: my_model with score 0.8324
# 2025-08-06 20:43:44,724 - INFO - MLTrainingEngine - Model 'my_model' saved to model_registry\training_models\my_model.pkl
# 2025-08-06 20:43:44,727 - INFO - Experiment_1754487798 - Experiment completed in 22.98 seconds
# 2025-08-06 20:43:44,727 - INFO - Experiment_1754487798 - Results saved to model_registry\training_models\experiments\experiment_1754487798.json
# 2025-08-06 20:43:44,729 - INFO - Experiment_1754487798 - Report generated: model_registry\training_models\experiments\report_1754487798.md
# 2025-08-06 20:43:44,730 - INFO - MLTrainingEngine - Model report generated: model_registry\training_models\experiments\report_1754487798.md
# 2025-08-06 20:43:44,730 - INFO - MLTrainingEngine - Model training completed in 23.09 seconds
# 2025-08-06 20:43:44,727 - INFO - Experiment_1754487798 - Results saved to model_registry\training_models\experiments\experiment_1754487798.json
# 2025-08-06 20:43:44,729 - INFO - Experiment_1754487798 - Report generated: model_registry\training_models\experiments\report_1754487798.md
# 2025-08-06 20:43:44,730 - INFO - MLTrainingEngine - Model report generated: model_registry\training_models\experiments\report_1754487798.md
# 2025-08-06 20:43:44,730 - INFO - MLTrainingEngine - Model training completed in 23.09 seconds
# {'model_name': 'my_model',
#  'model': RandomForestRegressor(),
#  'params': {'estimator': RandomForestRegressor(),
#   'param_space': {'n_estimators': [100, 200],
#    'max_depth': [None, 10],
#    'min_samples_split': [2]},
#   'max_iter': 15,
#   'cv': 5,
#   'scoring': 'accuracy',
#   'random_state': 42,
#   'n_jobs': -1,
#   'verbose': 0,
#   'maximize': True,
#   'time_budget': None,
#   'ensemble_surrogate': True,
#   'transfer_learning': True,
#   'optimization_strategy': 'auto',
#   'early_stopping': True,
#   'meta_learning': True,
#   'constraint_handling': 'auto',
#   'estimator__bootstrap': True,
#   'estimator__ccp_alpha': 0.0,
#   'estimator__criterion': 'squared_error',
#   'estimator__max_depth': None,
#   'estimator__max_features': 1.0,
#   'estimator__max_leaf_nodes': None,
#   'estimator__max_samples': None,
#   'estimator__min_impurity_decrease': 0.0,
#   'estimator__min_samples_leaf': 1,
#   'estimator__min_samples_split': 2,
#   'estimator__min_weight_fraction_leaf': 0.0,
#   'estimator__monotonic_cst': None,
#   'estimator__n_estimators': 100,
#   'estimator__n_jobs': None,
#   'estimator__oob_score': False,
#   'estimator__random_state': None,
#   'estimator__verbose': 0,
#   'estimator__warm_start': False},
#  'metrics': {'mse': 3169.5485057476335,
#   'rmse': 56.29874337627469,
#   'mae': 44.107523348442086,
#   'r2': 0.8324192479979334},
#  'feature_importance': array([0.00815349, 0.01063441, 0.01234374, 0.00682235, 0.00815811,
#         0.04771894, 0.31091427, 0.00691283, 0.00765355, 0.29614903,
#         0.00786095, 0.00733676, 0.00844025, 0.01415341, 0.00802265,
#         0.00686189, 0.02581077, 0.00745479, 0.03481588, 0.16378193]),
#  'training_time': 23.08506464958191}

# %% [markdown]
# # 📊 Model Evaluation
#
# After training our model, we need to evaluate its performance to understand how well it learned from the data.
#
# ### What This Does:
# - **Performance Metrics**: Calculates key regression metrics like MAE, MSE, RMSE, and R²
# - **Validation**: Uses the internal validation set to assess model quality
# - **Scoring**: Provides quantitative measures of prediction accuracy
#
# ### Expected Output:
# You'll see metrics showing how well the model performs on unseen data, helping you understand the quality of your trained model.

# %%
training_engine.evaluate_model()
# Out:
# 2025-08-06 20:43:44,848 - INFO - MLTrainingEngine - Using stored test data for evaluation
# {'model_name': 'my_model',
#  'metrics': {'mse': 2927.1280766016057,
#   'rmse': 54.10293962994623,
#   'mae': 42.29247041919631,
#   'r2': 0.7894957394280003,
#   'prediction_time': 0.0065135955810546875},
#  'detailed': False}

# %% [markdown]
# # 📋 Generate Comprehensive Training Report
#
# This section creates a detailed, formatted report of the entire training process and model performance.
#
# ### Report Contents:
# - **Model Information**: Details about the selected algorithm and hyperparameters
# - **Performance Metrics**: Complete evaluation results with statistical measures
# - **Training Process**: Summary of the automated training workflow
# - **Recommendations**: Insights and suggestions for model improvement
#
# ### Display Format:
# The report is rendered as Markdown for easy reading, with formatted tables, metrics, and explanations.

# %%
from IPython.display import Markdown, display


report = training_engine.generate_report()
display(Markdown(report))
# Out:
# # ML Training Engine Report
#
# **Generated**: 2025-08-06 20:43:44
#
# **Total Models Trained**: 1
# **Best Model**: my_model
#
# ## Configuration
#
# - **Task Type**: regression
# - **Random State**: 42
# - **CV Folds**: 5
# - **Optimization Strategy**: OptimizationStrategy.HYPERX
#
# ## Model Performance Comparison
#
# | Model Name | Type | Training Time (s) | Best | Metrics |
# |------------|------|------------------|------|----------|
# | my_model | RandomForestRegressor | 22.76 | ✅ | mse: 3169.5485, rmse: 56.2987, mae: 44.1075 |
#
# ## Detailed Model Information
#
# ### my_model
#
# **Model Type**: RandomForestRegressor
#
# **Parameters**:
# - estimator: RandomForestRegressor()
# - param_space: {'n_estimators': [100, 200], 'max_depth': [None, 10], 'min_samples_split': [2]}
# - max_iter: 15
# - cv: 5
# - scoring: accuracy
# - random_state: 42
# - n_jobs: -1
# - verbose: 0
# - maximize: True
# - time_budget: None
# - ensemble_surrogate: True
# - transfer_learning: True
# - optimization_strategy: auto
# - early_stopping: True
# - meta_learning: True
# - constraint_handling: auto
# - estimator__bootstrap: True
# - estimator__ccp_alpha: 0.0
# - estimator__criterion: squared_error
# - estimator__max_depth: None
# - estimator__max_features: 1.0
# - estimator__max_leaf_nodes: None
# - estimator__max_samples: None
# - estimator__min_impurity_decrease: 0.0
# - estimator__min_samples_leaf: 1
# - estimator__min_samples_split: 2
# - estimator__min_weight_fraction_leaf: 0.0
# - estimator__monotonic_cst: None
# - estimator__n_estimators: 100
# - estimator__n_jobs: None
# - estimator__oob_score: False
# - estimator__random_state: None
# - estimator__verbose: 0
# - estimator__warm_start: False
#
# **Performance Metrics**:
# - mse: 3169.548506
# - rmse: 56.298743
# - mae: 44.107523
# - r2: 0.832419
#
# **Top 10 Feature Importance**:
# 1. feature_6: 0.3109
# 2. feature_9: 0.2961
# 3. feature_19: 0.1638
# 4. feature_5: 0.0477
# 5. feature_18: 0.0348
# 6. feature_16: 0.0258
# 7. feature_13: 0.0142
# 8. feature_2: 0.0123
# 9. feature_1: 0.0106
# 10. feature_12: 0.0084
#
# ---

# %% [markdown]
# # 💾 Save the Trained Model
#
# Now that we have a trained and evaluated model, we'll save it to disk for future use.
#
# ### What This Does:
# - **Model Serialization**: Converts the trained model into a file format (.pkl)
# - **Persistent Storage**: Saves to `model_registry/training_models/` directory
# - **Reusability**: Enables loading the model later without retraining
# - **Version Control**: Maintains model versions for comparison and rollback
#
# ### File Location:
# The model will be saved as `model_registry/training_models/my_model.pkl`

# %%
training_engine.save_model("my_model")
# Out:
# 2025-08-06 20:43:44,885 - INFO - MLTrainingEngine - Model 'my_model' saved to model_registry\training_models\my_model.pkl
# 'model_registry\\training_models\\my_model.pkl'

# %%
from kolosal_automl.modules.engine.inference_engine import InferenceEngine
inference_engine = InferenceEngine()

inference_engine.load_model("model_registry/training_models/my_model.pkl")
# Out:
# 2025-08-06 20:48:32,632 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Advanced resource management configured with 4 threads
# 2025-08-06 20:48:33,954 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - SIMD optimizer initialized
# 2025-08-06 20:48:33,955 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Result cache initialized with 1000 entries
# 2025-08-06 20:48:33,954 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - SIMD optimizer initialized
# 2025-08-06 20:48:33,955 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Result cache initialized with 1000 entries
# 2025-08-06 20:48:33,983 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - JIT compiler enabled for inference optimization
# 2025-08-06 20:48:33,984 - INFO - kolosal_automl.modules.engine.mixed_precision - Mixed precision enabled
# 2025-08-06 20:48:33,985 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Mixed precision enabled for inference
# 2025-08-06 20:48:33,985 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Streaming pipeline available for batch inference
# 2025-08-06 20:48:33,987 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Resource monitoring started
# 2025-08-06 20:48:33,987 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Inference engine initialized with model version 1.0
# 2025-08-06 20:48:33,988 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Loading model from model_registry/training_models/my_model.pkl
# 2025-08-06 20:48:33,983 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - JIT compiler enabled for inference optimization
# 2025-08-06 20:48:33,984 - INFO - kolosal_automl.modules.engine.mixed_precision - Mixed precision enabled
# 2025-08-06 20:48:33,985 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Mixed precision enabled for inference
# 2025-08-06 20:48:33,985 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Streaming pipeline available for batch inference
# 2025-08-06 20:48:33,987 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Resource monitoring started
# 2025-08-06 20:48:33,987 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Inference engine initialized with model version 1.0
# 2025-08-06 20:48:33,988 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Loading model from model_registry/training_models/my_model.pkl
# 2025-08-06 20:48:34,000 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Auto-detected model type: ModelType.SKLEARN
# 2025-08-06 20:48:34,011 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Using JIT compilation for model acceleration
# 2025-08-06 20:48:34,000 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Auto-detected model type: ModelType.SKLEARN
# 2025-08-06 20:48:34,011 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Using JIT compilation for model acceleration
# 2025-08-06 20:48:34,012 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Warming up model with 32 samples...
# 2025-08-06 20:48:34,013 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Model warm-up failed: X has 10 features, but RandomForestRegressor is expecting 20 features as input.
# 2025-08-06 20:48:34,012 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Warming up model with 32 samples...
# 2025-08-06 20:48:34,013 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Model warm-up failed: X has 10 features, but RandomForestRegressor is expecting 20 features as input.
# 2025-08-06 20:48:34,132 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - CPU usage (99.7%) above threshold, enabling throttling
# 2025-08-06 20:48:34,135 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Model loaded successfully in 0.15s
# 2025-08-06 20:48:34,132 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - CPU usage (99.7%) above threshold, enabling throttling
# 2025-08-06 20:48:34,135 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Model loaded successfully in 0.15s
# True
# 2025-08-06 20:48:44,250 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - CPU usage (0.0%) below threshold, disabling throttling

# %% [markdown]
# # 🔮 Model Prediction
#
# Now that we have loaded our trained model, we can use it to make predictions on new data.
#
# ### What We'll Do
# - **Generate New Test Data**: Create a small sample array to test predictions
# - **Make Predictions**: Use the trained model to predict target values
# - **Display Results**: Show both input features and predicted outputs
#
# ### Outcome
# Demonstration of how the trained model performs on unseen data, showcasing the practical application of our AutoML pipeline.

# %%
# Generate some test data for prediction (5 samples with 20 features each)
import numpy as np

# Create a small test array with the same number of features as our training data
test_data = np.random.randn(5, 20)

print("Test data shape:", test_data.shape)
print("\nSample test data (first 3 samples, first 5 features):")
print(test_data[:3, :5])

# Make predictions using the loaded model
_, predictions, _ = inference_engine.predict(test_data)

print(f"\nPredictions for {len(test_data)} samples:")
print(predictions)

# Display results in a more readable format
print("\n" + "="*50)
print("PREDICTION RESULTS")
print("="*50)
for i, pred in enumerate(predictions):
    print(f"Sample {i+1}: {pred:.4f}")
# Out:
# Test data shape: (5, 20)
#
# Sample test data (first 3 samples, first 5 features):
# [[-0.57454698 -0.41986346 -1.50487599  0.12598395  0.02996544]
#  [ 0.22940325 -1.08113711  0.75053612  0.69822084 -0.86998019]
#  [ 1.03186798  1.34580327  0.73725253 -1.09161119 -0.63682645]]
#
# Predictions for 5 samples:
# [  26.3905134   -38.14230437  166.25675717 -114.99146015  -86.85265942]
#
# ==================================================
# PREDICTION RESULTS
# ==================================================
# Sample 1: 26.3905
# Sample 2: -38.1423
# Sample 3: 166.2568
# Sample 4: -114.9915
# Sample 5: -86.8527

# %% [markdown]
# # 🎉 Tutorial Complete!
#
# Congratulations! You've successfully completed the Kolosal AutoML optimal training tutorial.
#
# ## What You've Accomplished:
# ✅ **Imported** essential AutoML libraries
# ✅ **Configured** optimal training settings with device optimization
# ✅ **Generated** synthetic regression data for testing
# ✅ **Trained** an automated machine learning model
# ✅ **Evaluated** model performance with comprehensive metrics
# ✅ **Generated** a detailed training report
# ✅ **Saved** the model for future use
# ✅ **Loaded** and tested the saved model
# ✅ **Made predictions** on new data
#
# ## Next Steps:
# - Try with your own datasets
# - Experiment with different task types (classification)
# - Explore advanced configuration options
# - Compare multiple models using the benchmarking features
#
# Happy machine learning! 🚀
