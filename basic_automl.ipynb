# %% [markdown]
# # Kolosal AutoML Tutorial: Basic AutoML🚀
#
# Welcome! In this notebook, we'll demonstrate how to use **Kolosal AutoML** to build a regression model with minimal effort. We'll use the California Housing dataset as an example and walk through the entire pipeline: loading data, training a model, evaluating it, and generating a performance report.

# %% [markdown]
# ## 📥 Step 1: Load the Dataset
#
# We use the `fetch_california_housing` dataset from `sklearn.datasets`. This built-in dataset contains information about California districts, including features like median income, house age, and average rooms. Our target is the median house value.

# %%
from sklearn.datasets import fetch_california_housing


housing = fetch_california_housing(as_frame=True)
df = housing.frame
df.rename(columns={'MedHouseVal': 'target'}, inplace=True)

# %% [markdown]
# ## 🧹 Step 2: Prepare Features and Target Variable
#
# We rename the target column and separate the features (`X`) and the target (`y`). This is a standard practice for supervised learning tasks.

# %%
X = df.drop(columns=['target']).values
y = df['target'].values

# %% [markdown]
# ## ⚙️ Step 3: Configure Kolosal AutoML
#
# We import the Kolosal AutoML training engine and its configuration. We then create a configuration for a regression task.

# %%
from kolosal_automl.modules.engine.train_engine import MLTrainingEngine
from kolosal_automl.modules.configs import MLTrainingEngineConfig, TaskType

config = MLTrainingEngineConfig(
    task_type=TaskType.REGRESSION,
    enable_jit_compilation=True,      # Enable JIT compilation
    enable_mixed_precision=True,      # Enable mixed precision training
    enable_adaptive_hyperopt=True,    # Enable advanced hyperparameter optimization
    enable_streaming=True,            # Enable streaming for large datasets
)
trainer = MLTrainingEngine(config)
# Out:
# 2025-08-06 20:06:48,926 - INFO - MLTrainingEngine - Experiment tracking enabled
# 2025-08-06 20:06:48,928 - INFO - MLTrainingEngine - Data preprocessor skipped for fast initialization
# 2025-08-06 20:06:48,928 - INFO - kolosal_automl.modules.engine.batch_processor - Memory-aware batch processing enabled
# 2025-08-06 20:06:48,930 - INFO - MLTrainingEngine - Batch processor initialized
# 2025-08-06 20:06:48,932 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Advanced resource management configured with 4 threads
# 2025-08-06 20:06:50,248 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - SIMD optimizer initialized
# 2025-08-06 20:06:50,250 - INFO - kolosal_automl.modules.engine.quantizer - Quantizer initialized with QuantizationType.INT8 type and QuantizationMode.DYNAMIC mode
# 2025-08-06 20:06:50,251 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Quantizer initialized with QuantizationType.INT8 type
# 2025-08-06 20:06:50,252 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Result cache initialized with 1000 entries
# 2025-08-06 20:06:50,281 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - JIT compiler enabled for inference optimization
# 2025-08-06 20:06:50,282 - INFO - kolosal_automl.modules.engine.mixed_precision - Mixed precision enabled
# 2025-08-06 20:06:50,283 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Mixed precision enabled for inference
# 2025-08-06 20:06:50,283 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Streaming pipeline available for batch inference
# 2025-08-06 20:06:50,285 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Resource monitoring started
# 2025-08-06 20:06:50,286 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Inference engine initialized with model version 1.0
# 2025-08-06 20:06:50,287 - INFO - MLTrainingEngine - Inference engine initialized
# 2025-08-06 20:06:50,287 - INFO - MLTrainingEngine - Model monitoring initialized
# 2025-08-06 20:06:50,288 - INFO - kolosal_automl.modules.engine.jit_compiler - JIT compiler initialization complete - Numba enabled
# 2025-08-06 20:06:50,288 - INFO - MLTrainingEngine - JIT compiler initialized
# 2025-08-06 20:06:50,288 - INFO - kolosal_automl.modules.engine.mixed_precision - Mixed precision manager initialization complete with FP16 enabled
# 2025-08-06 20:06:50,289 - INFO - kolosal_automl.modules.engine.mixed_precision - Mixed precision manager initialized. FP16 support: True
# 2025-08-06 20:06:50,289 - INFO - MLTrainingEngine - Mixed precision manager initialized
# 2025-08-06 20:06:50,290 - INFO - kolosal_automl.modules.engine.adaptive_hyperopt - Adaptive hyperparameter optimizer initialization complete with adaptive search enabled
# 2025-08-06 20:06:50,290 - INFO - MLTrainingEngine - Adaptive hyperparameter optimizer initialized
# 2025-08-06 20:06:50,291 - INFO - kolosal_automl.modules.engine.streaming_pipeline - Streaming data pipeline initialization complete with parallel processing enabled
# 2025-08-06 20:06:50,291 - INFO - MLTrainingEngine - Streaming pipeline initialized
# 2025-08-06 20:06:50,292 - INFO - MLTrainingEngine - ML Training Engine v0.1.4 initialized with task type: TaskType.REGRESSION
# 2025-08-06 20:06:50,293 - INFO - MLTrainingEngine - GPU usage enabled with memory fraction: 0.8
# 2025-08-06 20:06:50,294 - INFO - MLTrainingEngine - Model types registered for auto discovery
# 2025-08-06 20:06:50,437 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - CPU usage (90.1%) above threshold, enabling throttling
# 2025-08-06 20:07:00,566 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - CPU usage (0.0%) below threshold, disabling throttling
# 2025-08-06 20:07:30,932 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - CPU usage (116.4%) above threshold, enabling throttling
# 2025-08-06 20:07:41,057 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - CPU usage (0.0%) below threshold, disabling throttling

# %% [markdown]
# ## 🏋️ Step 4: Train the Model
#
# Now, we train the model using the `train_model()` function. Kolosal AutoML automatically selects and tunes the best model for the task.

# %%
trainer.train_model(X=X, y=y)
# Out:
# 2025-08-06 20:06:50,450 - INFO - MLTrainingEngine - Applied mixed precision optimization to training data
# 2025-08-06 20:06:50,451 - INFO - MLTrainingEngine - Initialized random_forest model for regression
# 2025-08-06 20:06:50,453 - INFO - MLTrainingEngine - Using minimal parameter grid for randomforest due to quick training mode or large dataset
# 2025-08-06 20:06:50,456 - INFO - Experiment_1754485608 - Started experiment 1754485608
# 2025-08-06 20:06:50,458 - INFO - Experiment_1754485608 - Configuration:
# {
#   "task_type": "regression",
#   "random_state": 42,
#   "n_jobs": -1,
#   "verbose": 1,
#   "cv_folds": 5,
#   "test_size": 0.2,
#   "stratify": true,
#   "optimization_strategy": "hyper_optimization_x",
#   "optimization_iterations": 50,
#   "optimization_timeout": null,
#   "early_stopping": true,
#   "early_stopping_rounds": 10,
#   "early_stopping_metric": null,
#   "feature_selection": true,
#   "feature_selection_method": "mutual_info",
#   "feature_selection_k": null,
#   "feature_importance_threshold": 0.01,
#   "model_path": "./models",
#   "model_registry_url": null,
#   "auto_version_models": true,
#   "experiment_tracking": true,
#   "experiment_tracking_platform": "mlflow",
#   "experiment_tracking_config": {},
#   "use_intel_optimization": true,
#   "use_gpu": true,
#   "gpu_memory_fraction": 0.8,
#   "memory_optimization": true,
#   "enable_distributed": false,
#   "distributed_strategy": "mirrored",
#   "distributed_config": {},
#   "checkpointing": true,
#   "checkpoint_interval": 10,
#   "checkpoint_path": "./models\\checkpoints",
#   "enable_pruning": false,
#   "auto_ml": "disabled",
#   "auto_ml_time_budget": null,
#   "ensemble_models": false,
#   "ensemble_method": "stacking",
#   "ensemble_size": 3,
#   "hyperparameter_tuning_cv": true,
#   "model_selection_criteria": "accuracy",
#   "auto_save": true,
#   "auto_save_on_shutdown": true,
#   "save_state_on_shutdown": false,
#   "load_best_model_after_train": true,
#   "enable_quantization": false,
#   "enable_model_compression": false,
#   "compression_method": "pruning",
#   "compute_permutation_importance": true,
#   "generate_feature_importance_report": true,
#   "generate_model_summary": true,
#   "generate_prediction_explanations": false,
#   "enable_model_export": true,
#   "export_formats": [
#     "sklearn",
#     "onnx"
#   ],
#   "auto_deploy": false,
#   "deployment_platform": null,
#   "deployment_config": {},
#   "log_level": "INFO",
#   "debug_mode": false,
#   "enable_telemetry": false,
#   "backend": "sklearn",
#   "enable_data_validation": true,
#   "enable_security": false,
#   "security_config": {},
#   "metadata": {},
#   "optimization_metric": null,
#   "preprocessing_config": {
#     "normalization": "standard",
#     "robust_percentiles": [
#       25.0,
#       75.0
#     ],
#     "handle_nan": true,
#     "handle_inf": true,
#     "nan_strategy": "mean",
#     "nan_fill_value": 0.0,
#     "inf_strategy": "max_value",
#     "pos_inf_fill_value": 10000000000.0,
#     "neg_inf_fill_value": -10000000000.0,
#     "inf_buffer": 1.0,
#     "copy_X": true,
#     "detect_outliers": true,
#     "outlier_method": "iqr",
#     "outlier_handling": "clip",
#     "outlier_contamination": 0.05,
#     "outlier_iqr_multiplier": 1.5,
#     "outlier_zscore_threshold": 3.0,
#     "outlier_percentiles": [
#       1.0,
#       99.0
#     ],
#     "feature_outlier_mask": [],
#     "clip_values": false,
#     "clip_min": -10000000000.0,
#     "clip_max": 10000000000.0,
#     "scale_shift": false,
#     "scale_offset": 0.0,
#     "custom_center_func": null,
#     "custom_scale_func": null,
#     "custom_normalization_fn": null,
#     "custom_transform_fn": null,
#     "custom_inverse_fn": null,
#     "categorical_encoding": "one_hot",
#     "categorical_max_categories": 20,
#     "auto_feature_selection": true,
#     "numeric_transformations": [],
#     "text_vectorization": "tfidf",
#     "text_max_features": 5000,
#     "dimension_reduction": null,
#     "dimension_reduction_target": null,
#     "datetime_features": true,
#     "image_preprocessing": {},
#     "handle_imbalance": false,
#     "imbalance_strategy": "smote",
#     "feature_interaction": false,
#     "feature_interaction_max": 10,
#     "custom_transformers": [],
#     "transformation_pipeline": [],
#     "parallel_processing": true,
#     "cache_preprocessing": true,
#     "verbosity": 1,
#     "enable_input_validation": true,
#     "input_size_limit": null,
#     "n_jobs": -1,
#     "chunk_size": null,
#     "cache_enabled": true,
#     "cache_size": 128,
#     "dtype": "<class 'numpy.float64'>",
#     "epsilon": 1e-10,
#     "debug_mode": false,
#     "version": "0.1.4"
#   },
#   "batch_processing_config": {
#     "initial_batch_size": 100,
#     "min_batch_size": 50,
#     "max_batch_size": 200,
#     "max_queue_size": 1000,
#     "batch_timeout": 1.0,
#     "num_workers": 4,
#     "adaptive_batching": true,
#     "batch_allocation_strategy": "dynamic",
#     "enable_priority_queue": true,
#     "priority_levels": 3,
#     "enable_monitoring": true,
#     "monitoring_interval": 2.0,
#     "enable_memory_optimization": true,
#     "enable_prefetching": true,
#     "prefetch_batches": 2,
#     "checkpoint_batches": false,
#     "checkpoint_interval": 100,
#     "error_handling": "retry",
#     "max_retries": 3,
#     "retry_delay": 0.5,
#     "distributed_processing": false,
#     "resource_allocation": {},
#     "item_timeout": 10.0,
#     "min_batch_interval": 0.0,
#     "processing_strategy": "ADAPTIVE",
#     "enable_adaptive_batching": true,
#     "reduce_batch_on_failure": true,
#     "max_batch_memory_mb": null,
#     "gc_batch_threshold": 32,
#     "monitoring_window": 100,
#     "max_workers": 4,
#     "enable_health_monitoring": true,
#     "health_check_interval": 5.0,
#     "memory_warning_threshold": 70.0,
#     "memory_critical_threshold": 85.0,
#     "queue_warning_threshold": 100,
#     "queue_critical_threshold": 500,
#     "debug_mode": false
#   },
#   "inference_config": {
#     "enable_intel_optimization": true,
#     "enable_batching": true,
#     "enable_quantization": true,
#     "model_cache_size": 5,
#     "model_precision": "fp32",
#     "max_batch_size": 64,
#     "timeout_ms": 100,
#     "enable_jit": true,
#     "enable_onnx": false,
#     "onnx_opset": 15,
#     "enable_tensorrt": false,
#     "runtime_optimization": true,
#     "fallback_to_cpu": true,
#     "thread_count": 20,
#     "warmup": true,
#     "warmup_iterations": 10,
#     "profiling": false,
#     "batching_strategy": "dynamic",
#     "output_streaming": false,
#     "debug_mode": false,
#     "memory_growth": true,
#     "custom_ops": [],
#     "use_platform_accelerator": true,
#     "platform_accelerator_config": {},
#     "model_version": "1.0",
#     "num_threads": 4,
#     "set_cpu_affinity": false,
#     "enable_model_quantization": false,
#     "enable_input_quantization": false,
#     "quantization_dtype": "int8",
#     "enable_request_deduplication": true,
#     "max_cache_entries": 1000,
#     "cache_ttl_seconds": 300,
#     "monitoring_window": 100,
#     "enable_monitoring": true,
#     "monitoring_interval": 10.0,
#     "throttle_on_high_cpu": true,
#     "cpu_threshold_percent": 90.0,
#     "memory_high_watermark_mb": 1024.0,
#     "memory_limit_gb": null,
#     "batch_timeout": 0.1,
#     "max_concurrent_requests": 8,
#     "initial_batch_size": 16,
#     "min_batch_size": 1,
#     "enable_adaptive_batching": true,
#     "enable_memory_optimization": true,
#     "enable_feature_scaling": false,
#     "enable_warmup": true,
#     "enable_quantization_aware_inference": false,
#     "enable_throttling": true,
#     "enable_jit_compilation": true,
#     "enable_mixed_precision": true,
#     "enable_streaming": true,
#     "streaming_batch_size": 1000,
#     "optimization_mode": "balanced",
#     "enable_fp16_optimization": false,
#     "enable_compiler_optimization": true,
#     "threadpoolctl_available": false,
#     "onnx_available": false,
#     "treelite_available": false,
#     "quantization_config": {
#       "quantization_type": "int8",
#       "quantization_mode": "dynamic",
#       "per_channel": false,
#       "symmetric": true,
#       "enable_cache": true,
#       "cache_size": 256,
#       "calibration_samples": 100,
#       "calibration_method": "percentile",
#       "percentile": 99.99,
#       "skip_layers": [],
#       "quantize_weights_only": false,
#       "quantize_activations": true,
#       "weight_bits": 8,
#       "activation_bits": 8,
#       "quantize_bias": true,
#       "bias_bits": 32,
#       "enable_mixed_precision": false,
#       "mixed_precision_layers": [],
#       "optimize_for": "performance",
#       "custom_quantization_config": {},
#       "enable_requantization": false,
#       "requantization_threshold": 0.1,
#       "use_percentile": false,
#       "min_percentile": 0.1,
#       "max_percentile": 99.9,
#       "error_on_nan": false,
#       "error_on_inf": false,
#       "outlier_threshold": null,
#       "num_bits": 8,
#       "optimize_memory": true,
#       "buffer_size": 0
#     },
#     "batch_processor_config": {
#       "initial_batch_size": 16,
#       "min_batch_size": 1,
#       "max_batch_size": 64,
#       "max_queue_size": 16,
#       "batch_timeout": 0.1,
#       "num_workers": 4,
#       "adaptive_batching": true,
#       "batch_allocation_strategy": "dynamic",
#       "enable_priority_queue": true,
#       "priority_levels": 3,
#       "enable_monitoring": true,
#       "monitoring_interval": 2.0,
#       "enable_memory_optimization": true,
#       "enable_prefetching": true,
#       "prefetch_batches": 2,
#       "checkpoint_batches": false,
#       "checkpoint_interval": 100,
#       "error_handling": "retry",
#       "max_retries": 3,
#       "retry_delay": 0.5,
#       "distributed_processing": false,
#       "resource_allocation": {},
#       "item_timeout": 10.0,
#       "min_batch_interval": 0.0,
#       "processing_strategy": "ADAPTIVE",
#       "enable_adaptive_batching": true,
#       "reduce_batch_on_failure": true,
#       "max_batch_memory_mb": null,
#       "gc_batch_threshold": 32,
#       "monitoring_window": 100,
#       "max_workers": 4,
#       "enable_health_monitoring": true,
#       "health_check_interval": 5.0,
#       "memory_warning_threshold": 70.0,
#       "memory_critical_threshold": 85.0,
#       "queue_warning_threshold": 100,
#       "queue_critical_threshold": 500,
#       "debug_mode": false
#     }
#   },
#   "quantization_config": {
#     "quantization_type": "int8",
#     "quantization_mode": "dynamic_per_batch",
#     "per_channel": false,
#     "symmetric": true,
#     "enable_cache": true,
#     "cache_size": 256,
#     "calibration_samples": 100,
#     "calibration_method": "percentile",
#     "percentile": 99.99,
#     "skip_layers": [],
#     "quantize_weights_only": false,
#     "quantize_activations": true,
#     "weight_bits": 8,
#     "activation_bits": 8,
#     "quantize_bias": true,
#     "bias_bits": 32,
#     "enable_mixed_precision": false,
#     "mixed_precision_layers": [],
#     "optimize_for": "performance",
#     "custom_quantization_config": {},
#     "enable_requantization": false,
#     "requantization_threshold": 0.1,
#     "use_percentile": false,
#     "min_percentile": 0.1,
#     "max_percentile": 99.9,
#     "error_on_nan": false,
#     "error_on_inf": false,
#     "outlier_threshold": null,
#     "num_bits": 8,
#     "optimize_memory": true,
#     "buffer_size": 0
#   },
#   "explainability_config": {
#     "enable_explainability": false,
#     "methods": [
#       "shap",
#       "feature_importance"
#     ],
#     "default_method": "shap",
#     "shap_algorithm": "auto",
#     "shap_samples": 100,
#     "lime_samples": 1000,
#     "feature_importance_permutations": 10,
#     "partial_dependence_features": [],
#     "partial_dependence_grid_points": 20,
#     "eli5_permutation_samples": 100,
#     "generate_summary": true,
#     "generate_plots": true,
#     "explainability_report_format": "html",
#     "store_explanations": true,
#     "explanation_cache_size": 100,
#     "enable_counterfactuals": false,
#     "counterfactual_method": "dice",
#     "custom_explainers": []
#   },
#   "monitoring_config": {
#     "enable_monitoring": true,
#     "drift_detection": true,
#     "drift_detection_method": "ks_test",
#     "drift_threshold": 0.05,
#     "drift_check_interval": "1h",
#     "monitoring_interval": "1h",
#     "performance_tracking": true,
#     "performance_metrics": [
#       "accuracy",
#       "latency"
#     ],
#     "performance_threshold": 0.1,
#     "alert_on_drift": true,
#     "alert_on_performance_drop": true,
#     "alert_channels": [
#       "log"
#     ],
#     "monitoring_report_interval": "1d",
#     "data_sampling_rate": 1.0,
#     "store_predictions": true,
#     "prediction_store_size": 10000,
#     "enable_auto_retraining": false,
#     "retraining_trigger_drift_threshold": 0.1,
#     "retraining_trigger_performance_drop": 0.05,
#     "export_metrics": false,
#     "metrics_export_format": "prometheus",
#     "custom_monitors": []
#   }
# }
# 2025-08-06 20:06:50,460 - INFO - Experiment_1754485608 - Model: {'model_type': 'random_forest', 'model_class': 'sklearn.ensemble._forest.RandomForestRegressor', 'task_type': 'regression'}
# 2025-08-06 20:06:50,461 - INFO - MLTrainingEngine - Feature selection enabled: mutual_info
# 2025-08-06 20:06:50,465 - INFO - MLTrainingEngine - Test data split: 4128 test samples reserved for final evaluation
# 2025-08-06 20:06:50,469 - INFO - MLTrainingEngine - Data split: 13209 training samples, 3303 validation samples, 4128 test samples
# 2025-08-06 20:06:50,587 - INFO - MLTrainingEngine - Fitting feature selector...
# 2025-08-06 20:06:51,066 - INFO - MLTrainingEngine - Selected 8 features out of 8
# 2025-08-06 20:06:51,067 - INFO - Experiment_1754485608 - Metrics for feature_selection: {'selected_feature_count': 8, 'total_feature_count': 8}
# 2025-08-06 20:06:51,192 - INFO - MLTrainingEngine - Starting hyperparameter optimization with OptimizationStrategy.HYPERX
# 2025-08-06 20:06:51,193 - INFO - MLTrainingEngine - Using 3-fold CV for large dataset with 20640 samples
# 2025-08-06 20:06:51,193 - INFO - MLTrainingEngine - Using HyperOptX with 15 iterations (reduced from 50 for performance)
# 2025-08-06 20:06:51,195 - INFO - Experiment_1754485608 - Metrics for optimization_setup: {'param_combinations': 'grid', 'cv_folds': 5, 'scoring': 'neg_mean_squared_error'}
# 2025-08-06 20:06:51,196 - INFO - kolosal_automl.modules.optimizer.hyperoptx - Problem features: {'n_samples': 13209, 'n_features': 8, 'density': 1.0, 'y_mean': 2.0669172639866757, 'y_std': 1.1514542450342449, 'y_skew': 0.975125803607256, 'n_params': 2, 'n_categorical': 2, 'n_numerical': 0}
# 2025-08-06 20:06:51,197 - INFO - kolosal_automl.modules.optimizer.hyperoptx - Selected optimization strategy: bayesian
# 2025-08-06 20:06:51,198 - INFO - kolosal_automl.modules.optimizer.hyperoptx - Initializing HyperOptX with 15 maximum iterations
# 2025-08-06 20:06:51,198 - INFO - kolosal_automl.modules.optimizer.hyperoptx - Phase 1: Initial exploration with 3 configurations
# 2025-08-06 20:06:54,355 - INFO - kolosal_automl.modules.optimizer.hyperoptx - Phase 2: Iterative optimization with 12 iterations
# 2025-08-06 20:07:05,462 - INFO - kolosal_automl.modules.optimizer.hyperoptx -   Iteration 6/15: budget=1.00, evaluating 1 candidates
# 2025-08-06 20:07:16,965 - INFO - kolosal_automl.modules.optimizer.hyperoptx -   Iteration 11/15: budget=1.00, evaluating 1 candidates
# 2025-08-06 20:07:26,950 - INFO - kolosal_automl.modules.optimizer.hyperoptx - Early stopping at iteration 13
# 2025-08-06 20:07:35,229 - INFO - kolosal_automl.modules.optimizer.hyperoptx -
# Optimization completed:
# 2025-08-06 20:07:35,229 - INFO - kolosal_automl.modules.optimizer.hyperoptx - Total iterations: 13
# 2025-08-06 20:07:35,230 - INFO - kolosal_automl.modules.optimizer.hyperoptx - Best score: -0.265899
# 2025-08-06 20:07:35,230 - INFO - kolosal_automl.modules.optimizer.hyperoptx - Best parameters: {'max_depth': None, 'n_estimators': 100}
# 2025-08-06 20:07:35,231 - INFO - kolosal_automl.modules.optimizer.hyperoptx - Time elapsed: 44.04 seconds
# 2025-08-06 20:07:35,233 - INFO - Experiment_1754485608 - Metrics for optimization: {'mean_cv_score': -0.28423819443592413, 'std_cv_score': 0.00966613957825611, 'optimization_time': 44.0371732711792}
# 2025-08-06 20:07:35,234 - INFO - MLTrainingEngine - Best CV score: -0.2842 ± 0.0097
# 2025-08-06 20:07:35,235 - INFO - MLTrainingEngine - Best parameters: {'max_depth': None, 'n_estimators': 100}
# 2025-08-06 20:07:35,344 - INFO - MLTrainingEngine - Evaluating model on validation data...
# 2025-08-06 20:07:35,415 - INFO - Experiment_1754485608 - Metrics for validation: {'mse': 0.2775370023300599, 'rmse': 0.5268178075293772, 'mae': 0.3463221171964883, 'r2': 0.7988844626014588}
# 2025-08-06 20:07:35,417 - INFO - MLTrainingEngine - Validation mse: 0.2775
# 2025-08-06 20:07:35,418 - INFO - MLTrainingEngine - Validation rmse: 0.5268
# 2025-08-06 20:07:35,418 - INFO - MLTrainingEngine - Validation mae: 0.3463
# 2025-08-06 20:07:35,419 - INFO - MLTrainingEngine - Validation r2: 0.7989
# 2025-08-06 20:07:35,552 - INFO - Experiment_1754485608 - Feature importance: {
#   "feature_0": 0.5275591321748022,
#   "feature_5": 0.13485736884788535,
#   "feature_7": 0.0880251758570175,
#   "feature_6": 0.0879970316109523,
#   "feature_1": 0.056818663981278966,
#   "feature_2": 0.04423055387595953,
#   "feature_4": 0.03098977134096682,
#   "feature_3": 0.029522302311137436
# }
# 2025-08-06 20:07:35,553 - INFO - MLTrainingEngine - Top 10 features by importance:
# 2025-08-06 20:07:35,554 - INFO - MLTrainingEngine -   feature_0: 0.5276
# 2025-08-06 20:07:35,555 - INFO - MLTrainingEngine -   feature_5: 0.1349
# 2025-08-06 20:07:35,555 - INFO - MLTrainingEngine -   feature_7: 0.0880
# 2025-08-06 20:07:35,556 - INFO - MLTrainingEngine -   feature_6: 0.0880
# 2025-08-06 20:07:35,557 - INFO - MLTrainingEngine -   feature_1: 0.0568
# 2025-08-06 20:07:35,558 - INFO - MLTrainingEngine -   feature_2: 0.0442
# 2025-08-06 20:07:35,558 - INFO - MLTrainingEngine -   feature_4: 0.0310
# 2025-08-06 20:07:35,558 - INFO - MLTrainingEngine -   feature_3: 0.0295
# 2025-08-06 20:07:35,665 - INFO - MLTrainingEngine - New best model: random_forest_1754485610 with score 0.7989
# 2025-08-06 20:07:35,736 - INFO - MLTrainingEngine - Model 'random_forest_1754485610' saved to ./models\random_forest_1754485610.pkl
# 2025-08-06 20:07:35,738 - INFO - Experiment_1754485608 - Experiment completed in 45.28 seconds
# 2025-08-06 20:07:35,739 - INFO - Experiment_1754485608 - Results saved to ./models\experiments\experiment_1754485608.json
# 2025-08-06 20:07:35,741 - INFO - Experiment_1754485608 - Report generated: ./models\experiments\report_1754485608.md
# 2025-08-06 20:07:35,742 - INFO - MLTrainingEngine - Model report generated: ./models\experiments\report_1754485608.md
# 2025-08-06 20:07:35,742 - INFO - MLTrainingEngine - Model training completed in 45.43 seconds
# {'model_name': 'random_forest_1754485610',
#  'model': RandomForestRegressor(),
#  'params': {'max_depth': None, 'n_estimators': 100},
#  'metrics': {'mse': 0.2775370023300599,
#   'rmse': 0.5268178075293772,
#   'mae': 0.3463221171964883,
#   'r2': 0.7988844626014588},
#  'feature_importance': array([0.52755913, 0.05681866, 0.04423055, 0.0295223 , 0.03098977,
#         0.13485737, 0.08799703, 0.08802518]),
#  'training_time': 45.43019700050354}

# %% [markdown]
# ## 📊 Step 5: Evaluate the Model
#
# Once training is complete, we evaluate the model's performance using built-in evaluation methods.

# %%
trainer.evaluate_model()
# Out:
# 2025-08-06 20:07:35,878 - INFO - MLTrainingEngine - Using stored test data for evaluation
# {'model_name': 'random_forest_1754485610',
#  'metrics': {'mse': 0.2655312019575462,
#   'rmse': 0.5152971977000711,
#   'mae': 0.336204313396318,
#   'r2': 0.7973676872131961,
#   'prediction_time': 0.08065199851989746},
#  'detailed': False}

# %% [markdown]
# ## 📝 Step 6: Generate and Display Performance Report
#
# Kolosal AutoML can generate a markdown report summarizing model performance, metrics, and key insights. We display it directly in the notebook using `IPython.display.Markdown`.

# %%
from IPython.display import Markdown, display


report = trainer.generate_report()
display(Markdown(report))
# Out:
# # ML Training Engine Report
#
# **Generated**: 2025-08-06 20:07:35
#
# **Total Models Trained**: 1
# **Best Model**: random_forest_1754485610
#
# ## Configuration
#
# - **Task Type**: regression
# - **Random State**: 42
# - **CV Folds**: 5
# - **Optimization Strategy**: OptimizationStrategy.HYPERX
#
# ## Model Performance Comparison
#
# | Model Name | Type | Training Time (s) | Best | Metrics |
# |------------|------|------------------|------|----------|
# | random_forest_1754485610 | RandomForestRegressor | 44.92 | ✅ | mse: 0.2775, rmse: 0.5268, mae: 0.3463 |
#
# ## Detailed Model Information
#
# ### random_forest_1754485610
#
# **Model Type**: RandomForestRegressor
#
# **Parameters**:
# - max_depth: None
# - n_estimators: 100
#
# **Performance Metrics**:
# - mse: 0.277537
# - rmse: 0.526818
# - mae: 0.346322
# - r2: 0.798884
#
# **Top 10 Feature Importance**:
# 1. feature_0: 0.5276
# 2. feature_5: 0.1349
# 3. feature_7: 0.0880
# 4. feature_6: 0.0880
# 5. feature_1: 0.0568
# 6. feature_2: 0.0442
# 7. feature_4: 0.0310
# 8. feature_3: 0.0295
#
# ---

# %% [markdown]
# ## ✅ Summary
#
# In this notebook, we have:
# - Loaded and explored a dataset
# - Configured and used Kolosal AutoML for regression
# - Trained, evaluated, and reported on model performance
#
# You can now try this with your own dataset by simply replacing the input features and target variable. Happy automating! 🔁
