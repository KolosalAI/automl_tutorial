# %% [markdown]
# # Kolosal AutoML Tutorial: Basic AutoML🚀
#
# Welcome! In this notebook, we'll demonstrate how to use **Kolosal AutoML** to build a regression model with minimal effort. We'll use the California Housing dataset as an example and walk through the entire pipeline: loading data, training a model, evaluating it, and generating a performance report.

# %% [markdown]
# ## 📥 Step 1: Load the Dataset
#
# We use the `fetch_california_housing` dataset from `sklearn.datasets`. This built-in dataset contains information about California districts, including features like median income, house age, and average rooms. Our target is the median house value.

# %%
from sklearn.datasets import fetch_california_housing


housing = fetch_california_housing(as_frame=True)
df = housing.frame
df.rename(columns={'MedHouseVal': 'target'}, inplace=True)

# %% [markdown]
# ## 🧹 Step 2: Prepare Features and Target Variable
#
# We rename the target column and separate the features (`X`) and the target (`y`). This is a standard practice for supervised learning tasks.

# %%
X = df.drop(columns=['target']).values
y = df['target'].values

# %% [markdown]
# ## ⚙️ Step 3: Configure Kolosal AutoML
#
# We import the Kolosal AutoML training engine and its configuration. We then create a configuration for a regression task.

# %%
from kolosal_automl.modules.engine.train_engine import MLTrainingEngine
from kolosal_automl.modules.configs import MLTrainingEngineConfig, TaskType

config = MLTrainingEngineConfig(
    task_type=TaskType.REGRESSION,
    enable_jit_compilation=True,      # Enable JIT compilation
    enable_mixed_precision=True,      # Enable mixed precision training
    enable_adaptive_hyperopt=True,    # Enable advanced hyperparameter optimization
    enable_streaming=True,            # Enable streaming for large datasets
)
trainer = MLTrainingEngine(config)
# Out:
# 2025-08-10 12:47:20,807 - INFO - MLTrainingEngine - Experiment tracking enabled
# 2025-08-10 12:47:20,810 - INFO - MLTrainingEngine - Data preprocessor skipped for fast initialization
# 2025-08-10 12:47:20,811 - INFO - kolosal_automl.modules.engine.batch_processor - Memory-aware batch processing enabled
# 2025-08-10 12:47:20,812 - INFO - MLTrainingEngine - Batch processor initialized
# 2025-08-10 12:47:20,815 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Advanced resource management configured with 4 threads
# 2025-08-10 12:47:22,147 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - SIMD optimizer initialized
# 2025-08-10 12:47:22,151 - INFO - kolosal_automl.modules.engine.quantizer - Quantizer initialized with QuantizationType.INT8 type and QuantizationMode.DYNAMIC mode
# 2025-08-10 12:47:22,152 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Quantizer initialized with QuantizationType.INT8 type
# 2025-08-10 12:47:22,154 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Result cache initialized with 1000 entries
# 2025-08-10 12:47:22,229 - INFO - kolosal_automl.modules.engine.jit_compiler - JIT compiler initialized with Numba support
# 2025-08-10 12:47:22,229 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - JIT compiler enabled for inference optimization
# d:\Works\Genta\codes\automl_tutorial\kolosal_automl\modules\engine\mixed_precision.py:183: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.torch_scaler = GradScaler(
# d:\Works\Genta\codes\automl_tutorial\.venv\lib\site-packages\torch\amp\grad_scaler.py:132: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn(
# 2025-08-10 12:47:23,547 - INFO - kolosal_automl.modules.engine.mixed_precision - PyTorch AMP scaler initialized
# 2025-08-10 12:47:23,547 - INFO - kolosal_automl.modules.engine.mixed_precision - Mixed precision enabled
# 2025-08-10 12:47:23,549 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Mixed precision enabled for inference
# 2025-08-10 12:47:23,549 - INFO - kolosal_automl.modules.engine.streaming_pipeline - Streaming pipeline initialized with chunk_size=1000, parallel=True, distributed=False
# 2025-08-10 12:47:23,550 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Streaming pipeline available for batch inference
# 2025-08-10 12:47:23,551 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Resource monitoring started
# 2025-08-10 12:47:23,552 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Inference engine initialized with model version 1.0
# 2025-08-10 12:47:23,552 - INFO - MLTrainingEngine - Inference engine initialized
# 2025-08-10 12:47:23,552 - INFO - MLTrainingEngine - Model monitoring initialized
# 2025-08-10 12:47:23,665 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - CPU usage (99.4%) above threshold, enabling throttling
# 2025-08-10 12:47:24,233 - INFO - kolosal_automl.modules.engine.jit_compiler - JIT compiler initialization complete - Numba enabled
# 2025-08-10 12:47:24,234 - INFO - MLTrainingEngine - JIT compiler initialized
# 2025-08-10 12:47:24,235 - INFO - kolosal_automl.modules.engine.mixed_precision - Mixed precision manager initialization complete with FP16 enabled
# 2025-08-10 12:47:24,236 - INFO - kolosal_automl.modules.engine.mixed_precision - Mixed precision manager initialized. FP16 support: True
# 2025-08-10 12:47:24,237 - INFO - MLTrainingEngine - Mixed precision manager initialized
# 2025-08-10 12:47:24,237 - INFO - kolosal_automl.modules.engine.adaptive_hyperopt - Adaptive hyperparameter optimizer initialized with optuna backend
# 2025-08-10 12:47:24,238 - INFO - kolosal_automl.modules.engine.adaptive_hyperopt - Adaptive hyperparameter optimizer initialization complete with adaptive search enabled
# 2025-08-10 12:47:24,238 - INFO - MLTrainingEngine - Adaptive hyperparameter optimizer initialized
# 2025-08-10 12:47:24,238 - INFO - kolosal_automl.modules.engine.streaming_pipeline - Streaming data pipeline initialization complete with parallel processing enabled
# 2025-08-10 12:47:24,239 - INFO - MLTrainingEngine - Streaming pipeline initialized
# 2025-08-10 12:47:24,240 - INFO - MLTrainingEngine - ML Training Engine v0.1.4 initialized with task type: TaskType.REGRESSION
# 2025-08-10 12:47:24,241 - INFO - MLTrainingEngine - GPU usage enabled with memory fraction: 0.8
# 2025-08-10 12:47:24,458 - INFO - MLTrainingEngine - Model types registered for auto discovery
# 2025-08-10 12:47:33,782 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - CPU usage (0.0%) below threshold, disabling throttling
# 2025-08-10 13:00:32,704 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1041.7 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:00:32,826 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:00:42,952 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1129.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:00:43,100 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:00:53,216 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1213.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:00:53,366 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:01:03,497 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1297.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:01:03,611 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:01:13,721 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1385.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:01:13,845 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:01:23,964 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1472.7 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:01:24,075 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:01:34,183 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1562.7 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:01:34,324 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:01:44,443 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1648.7 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:01:44,592 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:01:54,722 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1735.7 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:01:54,898 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:02:05,030 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1821.7 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:02:05,178 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:02:15,290 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1821.7 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:02:15,447 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:02:25,559 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1885.7 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:02:25,697 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:02:35,812 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1913.2 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:02:35,954 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:02:46,061 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1996.6 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:02:46,202 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:02:56,311 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (2075.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:02:56,464 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:03:06,583 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (2159.7 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:03:06,723 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:03:16,837 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (2242.7 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:03:16,992 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:03:27,104 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (2324.6 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:03:27,239 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:03:37,355 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (2407.6 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:03:37,503 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:03:47,621 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (2489.6 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:03:47,864 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:03:57,986 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (2562.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:03:58,161 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:04:08,278 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (2639.2 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:04:08,410 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:04:18,533 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (2710.7 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:04:18,671 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:04:28,783 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (2770.2 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:04:28,925 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:04:39,034 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (2834.6 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:04:39,193 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:04:49,318 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (2889.0 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:04:49,447 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:04:59,563 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (2958.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:04:59,685 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:05:09,806 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3006.5 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:05:09,966 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:05:20,089 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:05:20,231 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:05:30,348 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:05:30,466 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:05:40,591 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:05:40,702 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:05:50,811 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:05:50,954 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:06:01,071 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:06:01,404 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:06:11,534 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:06:11,645 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:06:21,763 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:06:21,909 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:06:32,037 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:06:32,172 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:06:42,297 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:06:42,424 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:06:52,546 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:06:52,672 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:07:02,782 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:07:02,925 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:07:13,042 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:07:13,202 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:07:23,316 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:07:23,469 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:07:33,584 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:07:33,703 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:07:43,828 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:07:43,939 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:07:54,049 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:07:54,165 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:08:04,287 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:08:04,397 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:08:14,518 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:08:14,626 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:08:24,749 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:08:24,865 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:08:34,992 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:08:35,100 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:08:45,213 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:08:45,315 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:08:55,438 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:08:55,539 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:09:05,663 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:09:05,774 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:09:15,883 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:09:16,016 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:09:26,131 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:09:26,279 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:09:36,408 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:09:36,626 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:09:46,740 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:09:46,880 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:09:56,989 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:09:57,134 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:10:07,252 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:10:07,392 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:10:17,508 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:10:17,636 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:10:27,750 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:10:27,884 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:10:38,005 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:10:38,144 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:10:48,256 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:10:48,394 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:10:58,512 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:10:58,693 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:11:08,818 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:11:08,954 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:11:19,076 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:11:19,231 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:11:29,345 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:11:29,530 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:11:39,648 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:11:39,816 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:11:49,942 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:11:50,096 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:12:00,218 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:12:00,369 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:12:10,479 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:12:10,631 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:12:20,760 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:12:20,920 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:12:31,030 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:12:31,186 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:12:41,304 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:12:41,441 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:12:51,564 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:12:51,719 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:13:01,828 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:13:01,956 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:13:12,071 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:13:12,200 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:13:22,314 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:13:22,489 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:13:32,598 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:13:32,730 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:13:42,848 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:13:43,007 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:13:53,111 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:13:53,234 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:14:03,357 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:14:03,471 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:14:13,582 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:14:13,710 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:14:23,817 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:14:23,980 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:14:34,103 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:14:34,250 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:14:44,376 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:14:44,499 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:14:54,611 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:14:54,750 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:15:04,867 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:15:04,987 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:15:15,103 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:15:15,218 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:15:25,346 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:15:25,468 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:15:35,586 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:15:35,715 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:15:45,833 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:15:45,963 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:15:56,092 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3052.4 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:15:56,216 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:16:06,331 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3043.3 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:16:06,437 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:16:16,550 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3043.3 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:16:16,682 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:16:26,812 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3043.3 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:16:26,975 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:16:37,096 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3043.3 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:16:37,298 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:16:47,415 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3043.3 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:16:47,534 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:16:57,658 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3043.3 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:16:57,793 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:17:07,917 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3043.3 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:17:08,078 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:17:18,186 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3043.3 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:17:18,350 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:17:28,480 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3043.3 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:17:28,644 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:17:38,764 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3043.3 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:17:38,933 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:17:49,044 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3043.3 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:17:49,194 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:17:59,319 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3043.3 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:17:59,474 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:18:09,596 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3043.3 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:18:09,747 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:18:19,861 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3043.3 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:18:19,987 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:18:30,103 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3043.3 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:18:30,254 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:18:40,377 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3043.3 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:18:40,540 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:18:50,667 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3043.3 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:18:50,836 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:19:00,946 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3043.3 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:19:01,079 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:19:11,204 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3043.3 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:19:11,343 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:19:21,460 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3043.3 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:19:21,604 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:19:31,712 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3043.3 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:19:31,867 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:19:41,979 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3043.3 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:19:42,126 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:19:52,246 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3043.3 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:19:52,360 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:20:02,480 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3043.3 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:20:02,604 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:20:12,722 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3043.3 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:20:12,848 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:20:22,959 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3043.3 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:20:23,102 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:20:33,221 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3043.3 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:20:33,337 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:20:43,466 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3043.3 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:20:43,592 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:20:53,707 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (3043.3 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:20:53,833 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:21:03,948 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (2818.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:21:04,106 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:21:14,213 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (2818.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:21:14,327 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:21:24,434 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (2818.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:21:24,542 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:21:34,659 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (2818.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:21:34,775 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:21:44,899 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (2818.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:21:45,021 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:21:55,145 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (2818.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:21:55,272 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:22:05,387 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (2818.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:22:05,538 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:22:15,655 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (2818.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:22:15,770 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:22:25,888 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (2818.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:22:26,014 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:22:36,122 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (2818.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:22:36,233 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:22:46,351 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (2818.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:22:46,457 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:22:56,582 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (2818.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:22:56,709 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:23:06,819 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (2818.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:23:06,930 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:23:17,047 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (2818.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:23:17,159 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:23:27,268 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (2818.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:23:27,382 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 13:23:37,488 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (2818.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 13:23:37,612 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# ...
# 2025-08-10 16:01:19,807 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:01:29,917 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.9 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:01:30,038 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:01:40,163 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.9 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:01:40,275 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:01:50,392 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.9 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:01:50,524 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:02:00,637 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.9 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:02:00,745 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:02:10,868 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:02:10,976 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:02:21,089 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:02:21,198 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:02:31,309 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:02:31,434 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:02:41,551 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:02:41,683 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:02:51,799 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:02:51,909 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:03:02,030 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:03:02,155 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:03:12,264 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:03:12,379 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:03:22,502 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:03:22,618 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:03:32,742 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:03:32,869 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:03:42,991 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:03:43,110 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:03:53,229 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:03:53,343 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:04:03,455 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:04:03,575 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:04:13,692 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:04:13,822 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:04:23,932 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:04:24,065 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:04:34,189 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:04:34,306 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:04:44,436 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:04:44,553 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:04:54,669 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:04:54,787 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:05:04,907 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:05:05,075 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:05:15,194 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:05:15,335 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:05:25,451 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:05:25,643 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:05:35,762 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:05:35,895 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:05:46,012 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.8 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:05:46,193 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:05:56,305 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.9 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:05:56,442 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:06:06,563 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.9 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:06:06,704 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:06:16,817 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.9 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:06:16,966 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:06:27,089 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.9 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:06:27,223 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:06:37,352 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.9 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:06:37,490 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:06:47,617 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.9 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:06:47,756 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:06:57,868 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.9 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:06:58,011 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:07:08,132 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.9 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:07:08,267 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:07:18,396 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.9 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:07:18,579 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:07:28,693 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.9 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:07:28,810 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:07:38,938 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.9 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:07:39,049 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:07:49,162 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.9 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:07:49,279 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:07:59,396 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.9 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:07:59,516 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:08:09,634 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.9 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:08:09,750 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:08:19,859 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.9 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:08:19,976 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:08:30,104 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.9 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:08:30,215 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:08:40,321 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.9 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:08:40,457 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:08:50,584 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.9 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:08:50,728 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:09:00,838 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.9 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:09:01,002 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:09:11,126 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.9 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:09:11,281 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:09:21,407 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.9 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:09:21,560 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:09:31,683 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.9 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:09:31,840 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:09:41,950 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.9 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:09:42,081 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage
# 2025-08-10 16:09:52,204 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - WARNING - Memory usage (1448.9 MB) exceeds high watermark, triggering garbage collection
# 2025-08-10 16:09:52,311 - kolosal_automl.modules.engine.inference_engine.InferenceEngine - INFO - Cache cleared due to high memory usage

# %% [markdown]
# ## 🏋️ Step 4: Train the Model
#
# Now, we train the model using the `train_model()` function. Kolosal AutoML automatically selects and tunes the best model for the task.

# %%
trainer.train_model(X=X, y=y)
# Out:
# 2025-08-10 12:47:24,585 - INFO - MLTrainingEngine - Applied mixed precision optimization to training data
# 2025-08-10 12:47:24,586 - INFO - MLTrainingEngine - Initialized random_forest model for regression
# 2025-08-10 12:47:24,586 - INFO - MLTrainingEngine - Using minimal parameter grid for randomforest due to quick training mode or large dataset
# 2025-08-10 12:47:24,587 - INFO - Experiment_1754804840 - Started experiment 1754804840
# 2025-08-10 12:47:24,588 - INFO - Experiment_1754804840 - Configuration:
# {
#   "task_type": "regression",
#   "random_state": 42,
#   "n_jobs": -1,
#   "verbose": 1,
#   "cv_folds": 5,
#   "test_size": 0.2,
#   "stratify": true,
#   "optimization_strategy": "hyper_optimization_x",
#   "optimization_iterations": 50,
#   "optimization_timeout": null,
#   "early_stopping": true,
#   "early_stopping_rounds": 10,
#   "early_stopping_metric": null,
#   "feature_selection": true,
#   "feature_selection_method": "mutual_info",
#   "feature_selection_k": null,
#   "feature_importance_threshold": 0.01,
#   "model_path": "./models",
#   "model_registry_url": null,
#   "auto_version_models": true,
#   "experiment_tracking": true,
#   "experiment_tracking_platform": "mlflow",
#   "experiment_tracking_config": {},
#   "use_intel_optimization": true,
#   "use_gpu": true,
#   "gpu_memory_fraction": 0.8,
#   "memory_optimization": true,
#   "enable_distributed": false,
#   "distributed_strategy": "mirrored",
#   "distributed_config": {},
#   "checkpointing": true,
#   "checkpoint_interval": 10,
#   "checkpoint_path": "./models\\checkpoints",
#   "enable_pruning": false,
#   "auto_ml": "disabled",
#   "auto_ml_time_budget": null,
#   "ensemble_models": false,
#   "ensemble_method": "stacking",
#   "ensemble_size": 3,
#   "hyperparameter_tuning_cv": true,
#   "model_selection_criteria": "accuracy",
#   "auto_save": true,
#   "auto_save_on_shutdown": true,
#   "save_state_on_shutdown": false,
#   "load_best_model_after_train": true,
#   "enable_quantization": false,
#   "enable_model_compression": false,
#   "compression_method": "pruning",
#   "compute_permutation_importance": true,
#   "generate_feature_importance_report": true,
#   "generate_model_summary": true,
#   "generate_prediction_explanations": false,
#   "enable_model_export": true,
#   "export_formats": [
#     "sklearn",
#     "onnx"
#   ],
#   "auto_deploy": false,
#   "deployment_platform": null,
#   "deployment_config": {},
#   "log_level": "INFO",
#   "debug_mode": false,
#   "enable_telemetry": false,
#   "backend": "sklearn",
#   "enable_data_validation": true,
#   "enable_security": false,
#   "security_config": {},
#   "metadata": {},
#   "optimization_metric": null,
#   "preprocessing_config": {
#     "normalization": "standard",
#     "robust_percentiles": [
#       25.0,
#       75.0
#     ],
#     "handle_nan": true,
#     "handle_inf": true,
#     "nan_strategy": "mean",
#     "nan_fill_value": 0.0,
#     "inf_strategy": "max_value",
#     "pos_inf_fill_value": 10000000000.0,
#     "neg_inf_fill_value": -10000000000.0,
#     "inf_buffer": 1.0,
#     "copy_X": true,
#     "detect_outliers": true,
#     "outlier_method": "iqr",
#     "outlier_handling": "clip",
#     "outlier_contamination": 0.05,
#     "outlier_iqr_multiplier": 1.5,
#     "outlier_zscore_threshold": 3.0,
#     "outlier_percentiles": [
#       1.0,
#       99.0
#     ],
#     "feature_outlier_mask": [],
#     "clip_values": false,
#     "clip_min": -10000000000.0,
#     "clip_max": 10000000000.0,
#     "scale_shift": false,
#     "scale_offset": 0.0,
#     "custom_center_func": null,
#     "custom_scale_func": null,
#     "custom_normalization_fn": null,
#     "custom_transform_fn": null,
#     "custom_inverse_fn": null,
#     "categorical_encoding": "one_hot",
#     "categorical_max_categories": 20,
#     "auto_feature_selection": true,
#     "numeric_transformations": [],
#     "text_vectorization": "tfidf",
#     "text_max_features": 5000,
#     "dimension_reduction": null,
#     "dimension_reduction_target": null,
#     "datetime_features": true,
#     "image_preprocessing": {},
#     "handle_imbalance": false,
#     "imbalance_strategy": "smote",
#     "feature_interaction": false,
#     "feature_interaction_max": 10,
#     "custom_transformers": [],
#     "transformation_pipeline": [],
#     "parallel_processing": true,
#     "cache_preprocessing": true,
#     "verbosity": 1,
#     "enable_input_validation": true,
#     "input_size_limit": null,
#     "n_jobs": -1,
#     "chunk_size": null,
#     "cache_enabled": true,
#     "cache_size": 128,
#     "dtype": "<class 'numpy.float64'>",
#     "epsilon": 1e-10,
#     "debug_mode": false,
#     "version": "0.1.4"
#   },
#   "batch_processing_config": {
#     "initial_batch_size": 100,
#     "min_batch_size": 50,
#     "max_batch_size": 200,
#     "max_queue_size": 1000,
#     "batch_timeout": 1.0,
#     "num_workers": 4,
#     "adaptive_batching": true,
#     "batch_allocation_strategy": "dynamic",
#     "enable_priority_queue": true,
#     "priority_levels": 3,
#     "enable_monitoring": true,
#     "monitoring_interval": 2.0,
#     "enable_memory_optimization": true,
#     "enable_prefetching": true,
#     "prefetch_batches": 2,
#     "checkpoint_batches": false,
#     "checkpoint_interval": 100,
#     "error_handling": "retry",
#     "max_retries": 3,
#     "retry_delay": 0.5,
#     "distributed_processing": false,
#     "resource_allocation": {},
#     "item_timeout": 10.0,
#     "min_batch_interval": 0.0,
#     "processing_strategy": "ADAPTIVE",
#     "enable_adaptive_batching": true,
#     "reduce_batch_on_failure": true,
#     "max_batch_memory_mb": null,
#     "gc_batch_threshold": 32,
#     "monitoring_window": 100,
#     "max_workers": 4,
#     "enable_health_monitoring": true,
#     "health_check_interval": 5.0,
#     "memory_warning_threshold": 70.0,
#     "memory_critical_threshold": 85.0,
#     "queue_warning_threshold": 100,
#     "queue_critical_threshold": 500,
#     "debug_mode": false
#   },
#   "inference_config": {
#     "enable_intel_optimization": true,
#     "enable_batching": true,
#     "enable_quantization": true,
#     "model_cache_size": 5,
#     "model_precision": "fp32",
#     "max_batch_size": 64,
#     "timeout_ms": 100,
#     "enable_jit": true,
#     "enable_onnx": false,
#     "onnx_opset": 15,
#     "enable_tensorrt": false,
#     "runtime_optimization": true,
#     "fallback_to_cpu": true,
#     "thread_count": 20,
#     "warmup": true,
#     "warmup_iterations": 10,
#     "profiling": false,
#     "batching_strategy": "dynamic",
#     "output_streaming": false,
#     "debug_mode": false,
#     "memory_growth": true,
#     "custom_ops": [],
#     "use_platform_accelerator": true,
#     "platform_accelerator_config": {},
#     "model_version": "1.0",
#     "num_threads": 4,
#     "set_cpu_affinity": false,
#     "enable_model_quantization": false,
#     "enable_input_quantization": false,
#     "quantization_dtype": "int8",
#     "enable_request_deduplication": true,
#     "max_cache_entries": 1000,
#     "cache_ttl_seconds": 300,
#     "monitoring_window": 100,
#     "enable_monitoring": true,
#     "monitoring_interval": 10.0,
#     "throttle_on_high_cpu": true,
#     "cpu_threshold_percent": 90.0,
#     "memory_high_watermark_mb": 1024.0,
#     "memory_limit_gb": null,
#     "batch_timeout": 0.1,
#     "max_concurrent_requests": 8,
#     "initial_batch_size": 16,
#     "min_batch_size": 1,
#     "enable_adaptive_batching": true,
#     "enable_memory_optimization": true,
#     "enable_feature_scaling": false,
#     "enable_warmup": true,
#     "enable_quantization_aware_inference": false,
#     "enable_throttling": true,
#     "enable_jit_compilation": true,
#     "enable_mixed_precision": true,
#     "enable_streaming": true,
#     "streaming_batch_size": 1000,
#     "optimization_mode": "balanced",
#     "enable_fp16_optimization": false,
#     "enable_compiler_optimization": true,
#     "threadpoolctl_available": false,
#     "onnx_available": false,
#     "treelite_available": false,
#     "quantization_config": {
#       "quantization_type": "int8",
#       "quantization_mode": "dynamic",
#       "per_channel": false,
#       "symmetric": true,
#       "enable_cache": true,
#       "cache_size": 256,
#       "calibration_samples": 100,
#       "calibration_method": "percentile",
#       "percentile": 99.99,
#       "skip_layers": [],
#       "quantize_weights_only": false,
#       "quantize_activations": true,
#       "weight_bits": 8,
#       "activation_bits": 8,
#       "quantize_bias": true,
#       "bias_bits": 32,
#       "enable_mixed_precision": false,
#       "mixed_precision_layers": [],
#       "optimize_for": "performance",
#       "custom_quantization_config": {},
#       "enable_requantization": false,
#       "requantization_threshold": 0.1,
#       "use_percentile": false,
#       "min_percentile": 0.1,
#       "max_percentile": 99.9,
#       "error_on_nan": false,
#       "error_on_inf": false,
#       "outlier_threshold": null,
#       "num_bits": 8,
#       "optimize_memory": true,
#       "buffer_size": 0
#     },
#     "batch_processor_config": {
#       "initial_batch_size": 16,
#       "min_batch_size": 1,
#       "max_batch_size": 64,
#       "max_queue_size": 16,
#       "batch_timeout": 0.1,
#       "num_workers": 4,
#       "adaptive_batching": true,
#       "batch_allocation_strategy": "dynamic",
#       "enable_priority_queue": true,
#       "priority_levels": 3,
#       "enable_monitoring": true,
#       "monitoring_interval": 2.0,
#       "enable_memory_optimization": true,
#       "enable_prefetching": true,
#       "prefetch_batches": 2,
#       "checkpoint_batches": false,
#       "checkpoint_interval": 100,
#       "error_handling": "retry",
#       "max_retries": 3,
#       "retry_delay": 0.5,
#       "distributed_processing": false,
#       "resource_allocation": {},
#       "item_timeout": 10.0,
#       "min_batch_interval": 0.0,
#       "processing_strategy": "ADAPTIVE",
#       "enable_adaptive_batching": true,
#       "reduce_batch_on_failure": true,
#       "max_batch_memory_mb": null,
#       "gc_batch_threshold": 32,
#       "monitoring_window": 100,
#       "max_workers": 4,
#       "enable_health_monitoring": true,
#       "health_check_interval": 5.0,
#       "memory_warning_threshold": 70.0,
#       "memory_critical_threshold": 85.0,
#       "queue_warning_threshold": 100,
#       "queue_critical_threshold": 500,
#       "debug_mode": false
#     }
#   },
#   "quantization_config": {
#     "quantization_type": "int8",
#     "quantization_mode": "dynamic_per_batch",
#     "per_channel": false,
#     "symmetric": true,
#     "enable_cache": true,
#     "cache_size": 256,
#     "calibration_samples": 100,
#     "calibration_method": "percentile",
#     "percentile": 99.99,
#     "skip_layers": [],
#     "quantize_weights_only": false,
#     "quantize_activations": true,
#     "weight_bits": 8,
#     "activation_bits": 8,
#     "quantize_bias": true,
#     "bias_bits": 32,
#     "enable_mixed_precision": false,
#     "mixed_precision_layers": [],
#     "optimize_for": "performance",
#     "custom_quantization_config": {},
#     "enable_requantization": false,
#     "requantization_threshold": 0.1,
#     "use_percentile": false,
#     "min_percentile": 0.1,
#     "max_percentile": 99.9,
#     "error_on_nan": false,
#     "error_on_inf": false,
#     "outlier_threshold": null,
#     "num_bits": 8,
#     "optimize_memory": true,
#     "buffer_size": 0
#   },
#   "explainability_config": {
#     "enable_explainability": false,
#     "methods": [
#       "shap",
#       "feature_importance"
#     ],
#     "default_method": "shap",
#     "shap_algorithm": "auto",
#     "shap_samples": 100,
#     "lime_samples": 1000,
#     "feature_importance_permutations": 10,
#     "partial_dependence_features": [],
#     "partial_dependence_grid_points": 20,
#     "eli5_permutation_samples": 100,
#     "generate_summary": true,
#     "generate_plots": true,
#     "explainability_report_format": "html",
#     "store_explanations": true,
#     "explanation_cache_size": 100,
#     "enable_counterfactuals": false,
#     "counterfactual_method": "dice",
#     "custom_explainers": []
#   },
#   "monitoring_config": {
#     "enable_monitoring": true,
#     "drift_detection": true,
#     "drift_detection_method": "ks_test",
#     "drift_threshold": 0.05,
#     "drift_check_interval": "1h",
#     "monitoring_interval": "1h",
#     "performance_tracking": true,
#     "performance_metrics": [
#       "accuracy",
#       "latency"
#     ],
#     "performance_threshold": 0.1,
#     "alert_on_drift": true,
#     "alert_on_performance_drop": true,
#     "alert_channels": [
#       "log"
#     ],
#     "monitoring_report_interval": "1d",
#     "data_sampling_rate": 1.0,
#     "store_predictions": true,
#     "prediction_store_size": 10000,
#     "enable_auto_retraining": false,
#     "retraining_trigger_drift_threshold": 0.1,
#     "retraining_trigger_performance_drop": 0.05,
#     "export_metrics": false,
#     "metrics_export_format": "prometheus",
#     "custom_monitors": []
#   }
# }
# 2025-08-10 12:47:24,589 - INFO - Experiment_1754804840 - Model: {'model_type': 'random_forest', 'model_class': 'sklearn.ensemble._forest.RandomForestRegressor', 'task_type': 'regression'}
# 2025-08-10 12:47:24,589 - INFO - MLTrainingEngine - Feature selection enabled: mutual_info
# 2025-08-10 12:47:24,592 - INFO - MLTrainingEngine - Test data split: 4128 test samples reserved for final evaluation
# 2025-08-10 12:47:24,594 - INFO - MLTrainingEngine - Data split: 13209 training samples, 3303 validation samples, 4128 test samples
# 2025-08-10 12:47:24,707 - INFO - MLTrainingEngine - Fitting feature selector...
# 2025-08-10 12:47:25,158 - INFO - MLTrainingEngine - Selected 8 features out of 8
# 2025-08-10 12:47:25,158 - INFO - Experiment_1754804840 - Metrics for feature_selection: {'selected_feature_count': 8, 'total_feature_count': 8}
# 2025-08-10 12:47:25,267 - INFO - MLTrainingEngine - Starting hyperparameter optimization with OptimizationStrategy.HYPERX
# 2025-08-10 12:47:25,268 - INFO - MLTrainingEngine - Using 3-fold CV for large dataset with 20640 samples
# 2025-08-10 12:47:25,268 - INFO - MLTrainingEngine - Using HyperOptX with 15 iterations (reduced from 50 for performance)
# 2025-08-10 12:47:25,284 - INFO - Experiment_1754804840 - Metrics for optimization_setup: {'param_combinations': 'grid', 'cv_folds': 5, 'scoring': 'neg_mean_squared_error'}
# 2025-08-10 12:47:25,285 - INFO - kolosal_automl.modules.optimizer.hyperoptx - Problem features: {'n_samples': 13209, 'n_features': 8, 'density': 1.0, 'y_mean': 2.0669172639866757, 'y_std': 1.1514542450342449, 'y_skew': 0.975125803607256, 'n_params': 2, 'n_categorical': 2, 'n_numerical': 0}
# 2025-08-10 12:47:25,287 - INFO - kolosal_automl.modules.optimizer.hyperoptx - Selected optimization strategy: bayesian
# 2025-08-10 12:47:25,288 - INFO - kolosal_automl.modules.optimizer.hyperoptx - Initializing HyperOptX with 15 maximum iterations
# 2025-08-10 12:47:25,288 - INFO - kolosal_automl.modules.optimizer.hyperoptx - Phase 1: Initial exploration with 3 configurations
# 2025-08-10 12:47:32,584 - INFO - kolosal_automl.modules.optimizer.hyperoptx - Phase 2: Iterative optimization with 12 iterations
# 2025-08-10 12:47:51,843 - INFO - kolosal_automl.modules.optimizer.hyperoptx -   Iteration 6/15: budget=1.00, evaluating 1 candidates
# 2025-08-10 12:48:12,607 - INFO - kolosal_automl.modules.optimizer.hyperoptx -   Iteration 11/15: budget=1.00, evaluating 1 candidates
# 2025-08-10 12:48:32,116 - INFO - kolosal_automl.modules.optimizer.hyperoptx - Early stopping at iteration 13
# 2025-08-10 12:48:45,976 - INFO - kolosal_automl.modules.optimizer.hyperoptx -
# Optimization completed:
# 2025-08-10 12:48:45,977 - INFO - kolosal_automl.modules.optimizer.hyperoptx - Total iterations: 13
# 2025-08-10 12:48:45,979 - INFO - kolosal_automl.modules.optimizer.hyperoptx - Best score: -0.266282
# 2025-08-10 12:48:45,980 - INFO - kolosal_automl.modules.optimizer.hyperoptx - Best parameters: {'max_depth': None, 'n_estimators': 100}
# 2025-08-10 12:48:45,981 - INFO - kolosal_automl.modules.optimizer.hyperoptx - Time elapsed: 80.70 seconds
# 2025-08-10 12:48:45,982 - INFO - Experiment_1754804840 - Metrics for optimization: {'mean_cv_score': -0.2850182111805304, 'std_cv_score': 0.010491474602671583, 'optimization_time': 80.69629645347595}
# 2025-08-10 12:48:45,983 - INFO - MLTrainingEngine - Best CV score: -0.2850 ± 0.0105
# 2025-08-10 12:48:45,984 - INFO - MLTrainingEngine - Best parameters: {'max_depth': None, 'n_estimators': 100}
# 2025-08-10 12:48:46,143 - INFO - MLTrainingEngine - Evaluating model on validation data...
# 2025-08-10 12:48:46,247 - INFO - Experiment_1754804840 - Metrics for validation: {'mse': 0.2775370023300599, 'rmse': 0.5268178075293772, 'mae': 0.3463221171964883, 'r2': 0.7988844626014588}
# 2025-08-10 12:48:46,248 - INFO - MLTrainingEngine - Validation mse: 0.2775
# 2025-08-10 12:48:46,249 - INFO - MLTrainingEngine - Validation rmse: 0.5268
# 2025-08-10 12:48:46,250 - INFO - MLTrainingEngine - Validation mae: 0.3463
# 2025-08-10 12:48:46,251 - INFO - MLTrainingEngine - Validation r2: 0.7989
# 2025-08-10 12:48:46,427 - INFO - Experiment_1754804840 - Feature importance: {
#   "feature_0": 0.5275591321748022,
#   "feature_5": 0.13485736884788535,
#   "feature_7": 0.0880251758570175,
#   "feature_6": 0.0879970316109523,
#   "feature_1": 0.056818663981278966,
#   "feature_2": 0.04423055387595953,
#   "feature_4": 0.03098977134096682,
#   "feature_3": 0.029522302311137436
# }
# 2025-08-10 12:48:46,428 - INFO - MLTrainingEngine - Top 10 features by importance:
# 2025-08-10 12:48:46,430 - INFO - MLTrainingEngine -   feature_0: 0.5276
# 2025-08-10 12:48:46,432 - INFO - MLTrainingEngine -   feature_5: 0.1349
# 2025-08-10 12:48:46,433 - INFO - MLTrainingEngine -   feature_7: 0.0880
# 2025-08-10 12:48:46,434 - INFO - MLTrainingEngine -   feature_6: 0.0880
# 2025-08-10 12:48:46,436 - INFO - MLTrainingEngine -   feature_1: 0.0568
# 2025-08-10 12:48:46,437 - INFO - MLTrainingEngine -   feature_2: 0.0442
# 2025-08-10 12:48:46,438 - INFO - MLTrainingEngine -   feature_4: 0.0310
# 2025-08-10 12:48:46,438 - INFO - MLTrainingEngine -   feature_3: 0.0295
# 2025-08-10 12:48:46,588 - INFO - MLTrainingEngine - New best model: random_forest_1754804844 with score 0.7989
# 2025-08-10 12:48:46,700 - INFO - MLTrainingEngine - Model 'random_forest_1754804844' saved to ./models\random_forest_1754804844.pkl
# 2025-08-10 12:48:46,704 - INFO - Experiment_1754804840 - Experiment completed in 82.11 seconds
# 2025-08-10 12:48:46,705 - INFO - Experiment_1754804840 - Results saved to ./models\experiments\experiment_1754804840.json
# 2025-08-10 12:48:46,708 - INFO - Experiment_1754804840 - Report generated: ./models\experiments\report_1754804840.md
# 2025-08-10 12:48:46,710 - INFO - MLTrainingEngine - Model report generated: ./models\experiments\report_1754804840.md
# 2025-08-10 12:48:46,711 - INFO - MLTrainingEngine - Model training completed in 82.24 seconds
# {'model_name': 'random_forest_1754804844',
#  'model': RandomForestRegressor(),
#  'params': {'max_depth': None, 'n_estimators': 100},
#  'metrics': {'mse': 0.2775370023300599,
#   'rmse': 0.5268178075293772,
#   'mae': 0.3463221171964883,
#   'r2': 0.7988844626014588},
#  'feature_importance': array([0.52755913, 0.05681866, 0.04423055, 0.0295223 , 0.03098977,
#         0.13485737, 0.08799703, 0.08802518]),
#  'training_time': 82.23805022239685}

# %% [markdown]
# ## 📊 Step 5: Evaluate the Model
#
# Once training is complete, we evaluate the model's performance using built-in evaluation methods.

# %%
trainer.evaluate_model()
# Out:
# 2025-08-10 12:48:46,876 - INFO - MLTrainingEngine - Using stored test data for evaluation
# {'model_name': 'random_forest_1754804844',
#  'metrics': {'mse': 0.2655312019575462,
#   'rmse': 0.5152971977000711,
#   'mae': 0.336204313396318,
#   'r2': 0.7973676872131961,
#   'prediction_time': 0.1617448329925537},
#  'detailed': False}

# %% [markdown]
# ## 📝 Step 6: Generate and Display Performance Report
#
# Kolosal AutoML can generate a markdown report summarizing model performance, metrics, and key insights. We display it directly in the notebook using `IPython.display.Markdown`.

# %%
from IPython.display import Markdown, display


report = trainer.generate_report()
display(Markdown(report))
# Out:
# # ML Training Engine Report
#
# **Generated**: 2025-08-10 12:48:47
#
# **Total Models Trained**: 1
# **Best Model**: random_forest_1754804844
#
# ## Configuration
#
# - **Task Type**: regression
# - **Random State**: 42
# - **CV Folds**: 5
# - **Optimization Strategy**: OptimizationStrategy.HYPERX
#
# ## Model Performance Comparison
#
# | Model Name | Type | Training Time (s) | Best | Metrics |
# |------------|------|------------------|------|----------|
# | random_forest_1754804844 | RandomForestRegressor | 81.51 | ✅ | mse: 0.2775, rmse: 0.5268, mae: 0.3463 |
#
# ## Detailed Model Information
#
# ### random_forest_1754804844
#
# **Model Type**: RandomForestRegressor
#
# **Parameters**:
# - max_depth: None
# - n_estimators: 100
#
# **Performance Metrics**:
# - mse: 0.277537
# - rmse: 0.526818
# - mae: 0.346322
# - r2: 0.798884
#
# **Top 10 Feature Importance**:
# 1. feature_0: 0.5276
# 2. feature_5: 0.1349
# 3. feature_7: 0.0880
# 4. feature_6: 0.0880
# 5. feature_1: 0.0568
# 6. feature_2: 0.0442
# 7. feature_4: 0.0310
# 8. feature_3: 0.0295
#
# ---

# %% [markdown]
# ## ✅ Summary
#
# In this notebook, we have:
# - Loaded and explored a dataset
# - Configured and used Kolosal AutoML for regression
# - Trained, evaluated, and reported on model performance
#
# You can now try this with your own dataset by simply replacing the input features and target variable. Happy automating! 🔁
